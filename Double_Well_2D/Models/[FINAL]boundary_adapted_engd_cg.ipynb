# %% [markdown]
# <a href="https://colab.research.google.com/github/StratosFair/Mean_Escape_Time/blob/main/Double_Well_2D/Models/%5BFINAL%5Dboundary_adapted_engd_cg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install FEniCS and mshr
try:
    import dolfin
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenics-install-release-real.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
    import dolfin

# %%
# Imports & FP64
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import scipy.special as special
from fenics import *
import mshr

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_dtype(torch.float64)

# %% [markdown]
# # Solving for the MET of a given SDE in an ellipse with "Boundary Adapted PINNs": comparison with FEM solution

# %% [markdown]
# ## 1) Setup
#
# For $a=2$ and $b=1.5$, let $
# \Omega := \{ (x,y)\in\mathbb{R}^2 : (x/a)^2 + (y/b)^2 < 1 \}$ be the ellipse centered at the origin with semi-axes $a$ (along $x$) and $b$ (along $y$). We consider a process driven by the double-well potential
#
# $$
# \Phi(x,y):= A\Bigl( 1-\exp\Bigl(-\frac{(x-1)^2+(y-0.5)^2}{\nu^2}\Bigr)\Bigr)
# \Bigl( 1-\exp\Bigl(-\frac{(x+1)^2+(y+0.5)^2}{\nu^2}\Bigr)\Bigr),
# $$
# with parameters $A>0$ (which controls the barrier height) and $\nu>0$ (which controls the width of the wells). Its associated drift is given by the negative gradient,
# $$
# b(x,y)= -\nabla\Phi(x,y)= \begin{pmatrix} b_1(x,y) \\ b_2(x,y) \end{pmatrix}.
# $$
#
# The stochastic differential equation solved by our process takes the form
# $$
# \begin{cases}
# dX_t = b(X_t)\,dt + \sigma(X_t)\,dW_t,\\
# X_0 = x\in\Omega,
# \end{cases}
# $$
# where the diffusion matrix is chosen as
# $$
# \sigma(x,y)= \begin{pmatrix}
# \sqrt{2\epsilon} & 0 \\
# 0 & \sqrt{\epsilon}
# \end{pmatrix}
# $$
# for some $\epsilon>0$, and $W_t$ is a two-dimensional standard Brownian motion.
#
# For all $x\in\Omega$, we define the exit time
# $$
# T(x):=\inf\{t\ge 0: X_t\in\partial\Omega\},
# $$
# and denote by
# $$
# \tau(x):=\mathbb{E}[T(x)]
# $$
# its first moment (the mean exit time).
#
# In this setting, one can show that $\tau$ is the (unique) solution of the boundary value problem
# $$
# \begin{cases}
# -\mathcal{L} u(x) = 1 \quad \text{for all } x\in\Omega,\\[1mm]
# u(x)= 0 \quad \text{for all } x\in\partial\Omega,
# \end{cases}
# $$
# where the infinitesimal generator $\mathcal{L}$ is given by
# $$
# \mathcal{L} u(x) = \epsilon\, u_{xx}(x) + \frac\epsilon2\, u_{yy}(x) + b_1(x,y)\, u_x(x) + b_2(x,y)\, u_y(x).
# $$
#
# **Derivation of the Weak Formulation:**
#
# Multiplying the strong form of the PDE
# $$
# \epsilon\, u_{xx} + \frac\epsilon2\, u_{yy} + b_1\, u_x + b_2\, u_y = -1 \quad \text{in } \Omega,
# $$
# by a test function $v\in H^1_0(\Omega)$ and integrating over $\Omega$, we obtain
# $$
# \int_\Omega \Bigl[ \epsilon\, u_{xx} +\frac\epsilon2\, u_{yy} + b_1\, u_x + b_2\, u_y \Bigr] v\,dx\,dy = -\int_\Omega v\,dx\,dy.
# $$
# Integration by parts on the second derivative terms (with $v=0$ on $\partial\Omega$) yields
# $$
# \int_\Omega \Bigl(\epsilon\, u_x\, v_x + \frac\epsilon2\, u_y\, v_y \Bigr) dx\,dy - \int_\Omega \Bigl( b_1\, u_x + b_2\, u_y \Bigr) v\,dx\,dy = \int_\Omega v\,dx\,dy.
# $$
# This is the weak formulation that we discretize using a Galerkin finite element method.

# %% [markdown]
# ## Approximating the true solution with FEM

# %%
# Parameters controlling the double-well potential and diffusion.
#numpy version
A_np = 5.0      # Barrier height for the double-well potential
nu_np = 1e-1    # Width parameter of the wells in the potential
eps_np = 12e-1   # Diffusion parameter
#fenics version
A = Constant(A_np)
nu = Constant(nu_np)
epsilon = Constant(eps_np)

# Create the elliptical domain Omega
a = 2.0
b = 1.5
domain = mshr.Ellipse(Point(0.0, 0.0), a, b)
mesh = mshr.generate_mesh(domain, 64)

# FE function space and boundary conditions
V = FunctionSpace(mesh, "CG", 1)

# Homogeneous Dirichlet BC (u = 0 on the boundary)
u_D = Constant(0.0)
def boundary(x, on_boundary):
    return on_boundary
bc = DirichletBC(V, u_D, boundary)

# Define the double-well potential and drift field
# using the spatial coordinates (x,y) from the mesh
x_coord = SpatialCoordinate(mesh)

# Double-well potential defined by:
#   Φ(x,y) = A [1 - exp(-((x-1)²+(y-0.5)²)/ν²)] [1 - exp(-((x+1)²+(y+0.5)²)/ν²)]
Phi = A * (1 - exp(-(((x_coord[0]-1)**2 + (x_coord[1]-0.5)**2) / (nu**2)))) \
        * (1 - exp(-(((x_coord[0]+1)**2 + (x_coord[1]+0.5)**2) / (nu**2))))

# The drift b(x,y) is the negative gradient of the potential.
db = -grad(Phi)
b1 = db[0]
b2 = db[1]

# Define the variational problem
u = TrialFunction(V)
v = TestFunction(V)

# The weak formulation reads:
# (ε u_x v_x + (ε/2) u_y v_y) dx - (b₁ u_x + b₂ u_y) v dx = ∫_Ω v dx

a_form = (epsilon * u.dx(0) * v.dx(0) + (epsilon/2) * u.dx(1) * v.dx(1)
          - (b1 * u.dx(0) + b2 * u.dx(1)) * v) * dx
L_form = v * dx

# Solve the problem
u_sol = Function(V)
solve(a_form == L_form, u_sol, bc)

# ------------------------
# Now u_h is the finite element solution (function of x and y)
# Example: Evaluating the solution at a specific point (x0, y0):
# pt = (0.0, 0.0)  # Example point at the center of the domain
# value_at_pt = u_sol(pt)
# print("The solution u_sol at point {} is: {}".format(pt, value_at_pt))

# %%
# plotting the solution
plt.figure(figsize=(7, 5))
p = plot(u_sol, title="FEM Solution for τ", mode="color")
plt.colorbar(p)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# plotting the mesh to see how the ellipse was discretized
# plt.figure(figsize=(7, 5))
# plot(mesh)
# plt.title("Mesh for the Elliptical Domain")
# plt.show()

# %% [markdown]
# ## Neural Network architecture and loss function
#
# Unlike the standard PINN, we will take an hypothesis space of Neural Networks which satisfy the boundary conditions explicitly. For this problem, we have homogenous zero Dirichlet boundary conditions, which we can enforce by multiplying our Neural Networks with an appropriate "smooth distance approximation" (see https://arxiv.org/abs/2104.08426). In accordance with the mentioned paper, we will take
# $$\varphi : x\mapsto \frac{\omega(x)}{\sqrt{\omega(x)^2 + \|\nabla\omega(x)\|^2}},$$
# where
# $$\omega(x,y) = 1 - \left(\frac{x}{a}\right)^2 - \left(\frac{y}{b}\right)^2,\ \ \text{and }\ \ \|\nabla\omega(x,y)\|^2 = \left(\frac{2x}{a^2}\right)^2 + \left(\frac{2y}{b^2}\right)^2 $$
# as our smooth distance approximation.
#
#
# With this modification, our objective to minimize becomes
# $$\hat u := \arg\min_{u\in\mathcal{NN}_\varphi}\ \frac1n \sum_{i=1}^n (\mathcal L u(x_i^c) + 1)^2 $$
# where $x_i^c$ are sampled i.i.d. with uniform distribution on $\Omega$, and the hypothesis space is given by
# $$\mathcal{NN}_\varphi:=\left\{x\mapsto \varphi(x) \cdot T_L\circ \sigma \circ T_{L-1}\circ\cdots\circ \sigma\circ T_1 (x)\right\}, $$
# for
# $$T_\ell : \mathbb{R}^{\ell-1}\to\mathbb{R}^\ell $$
# affine-linear maps of appropriate input-output dimensions, where
# $$\sigma :x \mapsto \begin{cases}x^2 &\text{ if } x\ge 0\\ 0 &\text{ if } x\le 0\end{cases} \quad \text{OR }\ \ \sigma : x\mapsto \operatorname{tanh}(x),$$
# is either the ReQU or hyperbolic tangent activation function, which is understood element-wise when applied to vectors.

# %%
# defining PINN w/ matching boundary condition
power = None #exponent k for relu^k, none for tanh
width = 30
depth = 3
gain = 2.0 #magnitude of weights at initialization

#define ReLU^k activation

class RePU(nn.Module):
    def __init__(self, power = power):
        super(RePU, self).__init__()
        self.power = power

    def forward(self, x):
        return torch.pow(torch.relu(x), self.power)

#define the smooth distance approximation
def smooth_distance(x, a=a, b=b):
    omega_x = 1 - (x[:,0]/a)**2 - (x[:,1]/b)**2
    grad_omega_x_sq = (2 * x[:,0]/a**2)**2 + (2 * x[:,1]/b**2)**2
    denominator = torch.sqrt(omega_x**2 + grad_omega_x_sq)
    return omega_x/denominator

#define hypothesis space
class BoundaryPINN(nn.Module):
    def __init__(self, power = power, width = width, depth = depth):
        super(BoundaryPINN,self).__init__()
        self.layers = nn.ModuleList()
        self.layers.append(nn.Linear(2, width))
        if isinstance(power, int):
            self.layers.append(RePU(power))
            for _ in range(depth-1) :
                self.layers.append(nn.Linear(width, width))
                self.layers.append(RePU(power))
        else :
            self.layers.append(nn.Tanh())
            for _ in range(depth-1) :
                self.layers.append(nn.Linear(width, width))
                self.layers.append(nn.Tanh())
        self.layers.append(nn.Linear(width, 1))
        self.mlp = nn.Sequential(*self.layers)

        #for dynamic weighting
        self.log_sigma_pde = nn.Parameter(torch.tensor(-0.5,
                                                        dtype=torch.float64))
        self.log_sigma_data = nn.Parameter(torch.tensor(-0.5,
                                                        dtype=torch.float64))

    def forward(self, x):
        output = x
        for layer in self.layers:
            output = layer(output)
        distance =  smooth_distance(x)
        return output * distance.unsqueeze(-1)

    def raw_forward(self, x):
        #returns the raw neural network output without multiplication by
        #distance to boundary
        return self.mlp(x)

#weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_normal_(m.weight, gain=gain)
        m.bias.data.fill_(gain)

# %%
# defining PDE Residual & Loss, enabling grad on x
def pde_residual(model, x, A, nu, epsilon, forcing=None):
    # ensure x is on the right device, float64, and requires grad
    x = x.clone().detach().to(device).requires_grad_(True)

    # unpack coordinates
    xs = x[:, 0]  # [N]
    ys = x[:, 1]  # [N]

    # squared distances to well centers
    d1_sq = (xs - 1.0)**2 + (ys - 0.5)**2
    d2_sq = (xs + 1.0)**2 + (ys + 0.5)**2

    # exponential terms
    exp1 = torch.exp(-d1_sq / (nu**2))  # e1
    exp2 = torch.exp(-d2_sq / (nu**2))  # e2

    # f1 = 1 - exp1, f2 = 1 - exp2
    f1 = 1.0 - exp1
    f2 = 1.0 - exp2

    # --- Compute ∇Φ analytically ---
    # ∂f1/∂x = (2/ν²)(x-1) exp1
    df1_dx = (2.0 / nu**2) * (xs - 1.0) * exp1
    df1_dy = (2.0 / nu**2) * (ys - 0.5) * exp1

    df2_dx = (2.0 / nu**2) * (xs + 1.0) * exp2
    df2_dy = (2.0 / nu**2) * (ys + 0.5) * exp2

    # ∇Φ = A * (∇f1 * f2 + f1 * ∇f2)
    dPhi_dx = A * (df1_dx * f2 + f1 * df2_dx)
    dPhi_dy = A * (df1_dy * f2 + f1 * df2_dy)

    # drift b = -∇Φ
    b1 = -dPhi_dx
    b2 = -dPhi_dy

    # forward through PINN
    tau = model(x)  # [N]

    # first derivatives
    grads = torch.autograd.grad(
        tau, x,
        grad_outputs=torch.ones_like(tau),
        create_graph=True,
    )[0]  # [N,2]
    tau_x, tau_y = grads[:, 0], grads[:, 1]

    # second derivatives
    tau_xx = torch.autograd.grad(
        tau_x, x,
        grad_outputs=torch.ones_like(tau_x),
        create_graph=True
    )[0][:, 0]

    tau_yy = torch.autograd.grad(
        tau_y, x,
        grad_outputs=torch.ones_like(tau_y),
        create_graph=True
    )[0][:, 1]

    # generator L[tau] = ε τ_xx + (ε/2) τ_yy + b1 τ_x + b2 τ_y
    phys = epsilon * tau_xx + 0.5 * epsilon * tau_yy + b1 * tau_x + b2 * tau_y

    # forcing term: default -1 (since -Lτ = 1 ⇒ Lτ = -1)
    if forcing is None:
        f_vals = -1.0
    elif isinstance(forcing, (int, float)):
        f_vals = float(forcing)
    elif callable(forcing):
        f_vals = forcing(x)
        if f_vals.dim() > 1:
            f_vals = f_vals.view(-1)
    else:
        raise ValueError(f"forcing must be None, float, or callable, got {type(forcing)}")

    if isinstance(f_vals, float) or isinstance(f_vals, int):
        f_vals = x.new_full((x.shape[0],), float(f_vals))

    # residual = L[tau](x) - f(x)
    r = phys - f_vals  # shape [N]
    return r


def loss_fn(res):
    return torch.mean(res.pow(2))

# %%
# Energy Hessian-vector product: Hv where H = d²ℒ/dθ² (full loss, including log terms)
def energy_hvp(v_vec_full):
    # ------------------------------------------------------------------
    # 1. Now include *all* parameters (including log-sigmas)
    # ------------------------------------------------------------------
    net_params = [p for p in model.parameters() if p.requires_grad]  # All trainable params

    n_net = sum(p.numel() for p in net_params)

    # ------------------------------------------------------------------
    # 2. Project the incoming CG direction onto the full space
    # ------------------------------------------------------------------
    v_net = v_vec_full[:n_net]

    # ------------------------------------------------------------------
    # 3. Make *dummy* copies that are leaves with requires_grad=True
    # ------------------------------------------------------------------
    dummy = [p.detach().clone().requires_grad_(True) for p in net_params]
    backup = [p.data.clone() for p in net_params]      # to restore later
    for p, d in zip(net_params, dummy):
        p.data.copy_(d)

    try:
        # --------------------------------------------------------------
        # 4. Forward pass – compute full ℒ
        # --------------------------------------------------------------
        # PDE loss component
        r = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing=None)
        pde_l = loss_fn(r)  # mean(r.pow(2))

        # Data loss component
        tau_p = model(x_data).squeeze(-1)
        data_l = (tau_p - tau_data).pow(2).mean()

        # Full total_l (including log terms)
        energy = (torch.exp(-2 * model.log_sigma_pde) * pde_l +
                  torch.exp(-2 * model.log_sigma_data) * data_l +
                  model.log_sigma_pde +
                  model.log_sigma_data)

        # --------------------------------------------------------------
        # 5. First-order gradient w.r.t. net_params
        # --------------------------------------------------------------
        g_list = torch.autograd.grad(
            energy, net_params,
            create_graph=True,
            allow_unused=True
        )
        # replace missing grads with zeros
        g_list = [g if g is not None else torch.zeros_like(p) for g, p in zip(g_list, net_params)]

        # --------------------------------------------------------------
        # 6. **Flatten inside the graph** – this keeps grad_fn alive
        # --------------------------------------------------------------
        grad_flat = torch.cat([g.flatten() for g in g_list])
        grad_flat = grad_flat * 1.0      # <- dummy op that forces a graph node

        # --------------------------------------------------------------
        # 7. Hessian-vector product
        # --------------------------------------------------------------
        hvp_list = torch.autograd.grad(
            grad_flat, net_params,
            grad_outputs=v_net,
            allow_unused=True
        )
        hvp_list = [h if h is not None else torch.zeros_like(p) for h, p in zip(hvp_list, net_params)]

        hvp_flat = torch.cat([h.flatten() for h in hvp_list])

        # --------------------------------------------------------------
        # 8. Pad back to the *full* parameter vector size (now same as n_net)
        # --------------------------------------------------------------
        hvp_full = torch.zeros_like(v_vec_full)
        hvp_full[:n_net] = hvp_flat
        return hvp_full

    finally:
        # --------------------------------------------------------------
        # 9. Restore the original model parameters (critical!)
        # --------------------------------------------------------------
        for p, b in zip(net_params, backup):
            p.data.copy_(b)

# %% [markdown]
# ## Computing an approximate data penalty regularization
#
# We sample a small subset $x_1, \ldots, x_{n_{d}} \in \Omega$ of points for which we compute approximate values $\tau^{MC}(x_1), \ldots, \tau^{MC}(x_{n_{d}}) $ by Monte Carlo. we will then use them to define a "data-fidelity" penalty term in the loss function:
# $$\text{Penalty}(\hat\tau_{NN}) = \frac{\lambda_{d}}{n_{d}} \sum_{i=1}^{n_d} \left(\tau^{MC}(x_i) - \hat\tau_{NN}(x_i)\right)^2, $$
# where $\lambda_{d}$ is a positive regularization parameter.

# %%
# generating some approximate true solutions in the domain

# sampling anchor points, uniform in the ellipse
@torch.no_grad()
def sample_ellipse(batch_size, a=2.0, b=1.5):
    """
    Sample uniformly in the ellipse: (x/a)^2 + (y/b)^2 <= 1.
    Uses rejection sampling in the bounding box [-a,a] x [-b,b].
    """
    collected = []  # List of [num_in, 2] tensors
    needed = batch_size
    while needed > 0:
        x = (2 * torch.rand(batch_size, device=device) - 1) * a  # [-a, a]
        y = (2 * torch.rand(batch_size, device=device) - 1) * b  # [-b, b]
        inside = (x/a)**2 + (y/b)**2 <= 1.0
        points_in = torch.stack([x[inside], y[inside]], dim=1)  # [num_in, 2]
        collected.append(points_in)
        needed -= points_in.shape[0]

    all_points = torch.cat(collected, dim=0)  # [total >= batch_size, 2]
    if all_points.shape[0] > batch_size:
        idx = torch.randperm(all_points.shape[0], device=device)[:batch_size]
        all_points = all_points[idx]
    return all_points


# 2) monte-carlo (euler-maruyama) approximation of tau at these points
@torch.no_grad()
def mc_exit_time(x0, A, nu, epsilon,
                 n_paths=128, dt=1e-3, max_steps=20000):
    """
    x0: [B,2] starting points
    Returns tau_hat: [B] = mean exit time from each x0.
    Any path still 'alive' after max_steps is counted as having exit time = max_steps*dt.
    """
    B = x0.shape[0]
    P = n_paths

    # Expand to per-path positions — CONTIGUOUS
    X = x0.unsqueeze(1).expand(B, P, 2).contiguous()  # [B,P,2]
    t = torch.zeros(B, P, device=device)
    alive = torch.ones(B, P, dtype=torch.bool, device=device)

    # Precompute diffusion
    dt_t = torch.as_tensor(dt, device=device, dtype=torch.float32)
    epsilon_t = torch.as_tensor(epsilon, device=device, dtype=torch.float32)
    sqrt_dt_x = torch.sqrt(2 * epsilon_t * dt_t)
    sqrt_dt_y = torch.sqrt(epsilon_t * dt_t)

    print_interval = max(1, max_steps // 100)  # at most 100 updates

    # --- Main loop: work on full batch, mask updates ---
    for step in range(max_steps):
        if not alive.any():
            break

        # Work on full [B,P,2] tensor — fully vectorized
        xs = X[..., 0]  # [B,P]
        ys = X[..., 1]  # [B,P]

        # --- Double-well drift: fully vectorized ---
        d1_sq = (xs - 1.0)**2 + (ys - 0.5)**2
        d2_sq = (xs + 1.0)**2 + (ys + 0.5)**2
        exp1 = torch.exp(-d1_sq / nu**2)
        exp2 = torch.exp(-d2_sq / nu**2)
        f1 = 1.0 - exp1
        f2 = 1.0 - exp2

        df1_dx = (2.0 / nu**2) * (xs - 1.0) * exp1
        df1_dy = (2.0 / nu**2) * (ys - 0.5) * exp1
        df2_dx = (2.0 / nu**2) * (xs + 1.0) * exp2
        df2_dy = (2.0 / nu**2) * (ys + 0.5) * exp2

        dPhi_dx = A * (df1_dx * f2 + f1 * df2_dx)
        dPhi_dy = A * (df1_dy * f2 + f1 * df2_dy)

        drift_x = -dPhi_dx * dt
        drift_y = -dPhi_dy * dt

        # Noise: full batch
        noise_x = sqrt_dt_x * torch.randn_like(xs)
        noise_y = sqrt_dt_y * torch.randn_like(ys)

        # Update ONLY alive paths
        X[..., 0] += drift_x
        X[..., 1] += drift_y
        X[..., 0][~alive] -= drift_x[~alive]  # undo
        X[..., 1][~alive] -= drift_y[~alive]  # undo
        X[..., 0] += noise_x
        X[..., 1] += noise_y
        X[..., 0][~alive] -= noise_x[~alive]
        X[..., 1][~alive] -= noise_y[~alive]

        t += dt
        t[~alive] -= dt  # don't advance time for dead paths

        # Check exit on full batch
        exited = (X[..., 0]/a)**2 + (X[..., 1]/b)**2 >= 1.0
        just_exited = exited & alive
        alive[just_exited] = False

        if step % print_interval == 0 or step == max_steps - 1:
            frac_alive = alive.float().mean().item()
            current_t = step * dt
            print(f"Step {step} | t = {current_t:.2f} | alive: {frac_alive*100:.3f}%", flush=True)


    tau_hat = t.mean(dim=1)  # [B]
    return tau_hat

# %%
# defining Uniform + Boundary Sampling functions in the ellipse
def sample_uniform_ellipse(N, a=2.0, b=1.5):
    """
    Uniform sampling in ellipse using rejection (same as sample_ellipse but fixed N)
    """
    return sample_ellipse(N, a=a, b=b)


def sample_boundary(N, a=2.0, b=1.5):
    """
    Uniform sampling on the boundary of the ellipse: (x/a)^2 + (y/b)^2 = 1
    Parameterized by angle θ ∈ [0, 2π)
    """
    theta = 2 * math.pi * torch.rand(N, device=device)
    x = a * torch.cos(theta)
    y = b * torch.sin(theta)
    return torch.stack([x, y], dim=1)  # [N,2]

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ### Training Parameters

# %%
# Training parameters
pool_size        = 8192
n_batches        = 16
batch_size       = pool_size // n_batches
n_epochs         = 5_000
learning_rate    = 5e-4

# model instantiation
model = BoundaryPINN(power, width, depth).to(device)
model.apply(init_weights)

opt   = torch.optim.Adam(list(model.parameters()), lr=learning_rate)

# scheduler: every `epochs_between_decays` epochs, multiply lr by gamma
num_decays = 100
epochs_between_decay = n_epochs // num_decays
final_factor = 1e-3
gamma = np.exp(np.log(final_factor) / num_decays)

scheduler = torch.optim.lr_scheduler.StepLR(
    opt,
    step_size=epochs_between_decay,  # decay every N epochs
    gamma=gamma                      # LR *= gamma at each decay
)

# %% [markdown]
# ### Generating the "data-fidelity" samples

# %%
# sample x_data
x_data = sample_uniform_ellipse(batch_size//2)

max_time = 15
dt = 2e-4

# precompute tau_data once
tau_data = mc_exit_time(
    x0       = x_data,
    A        = A_np,
    nu       = nu_np,
    epsilon  = eps_np,
    n_paths  = 256,
    dt       = dt,
    max_steps= int(max_time / dt)
)
# Out:
# Step 0 | t = 0.00 | alive: 99.379%
# Step 750 | t = 0.15 | alive: 58.812%
# Step 1500 | t = 0.30 | alive: 46.654%
# Step 2250 | t = 0.45 | alive: 38.544%
# Step 3000 | t = 0.60 | alive: 32.454%
# Step 3750 | t = 0.75 | alive: 27.371%
# Step 4500 | t = 0.90 | alive: 23.325%
# Step 5250 | t = 1.05 | alive: 19.865%
# Step 6000 | t = 1.20 | alive: 17.038%
# Step 6750 | t = 1.35 | alive: 14.569%
# Step 7500 | t = 1.50 | alive: 12.444%
# Step 8250 | t = 1.65 | alive: 10.678%
# Step 9000 | t = 1.80 | alive: 9.166%
# Step 9750 | t = 1.95 | alive: 7.913%
# Step 10500 | t = 2.10 | alive: 6.778%
# Step 11250 | t = 2.25 | alive: 5.870%
# Step 12000 | t = 2.40 | alive: 5.060%
# Step 12750 | t = 2.55 | alive: 4.326%
# Step 13500 | t = 2.70 | alive: 3.717%
# Step 14250 | t = 2.85 | alive: 3.194%
# Step 15000 | t = 3.00 | alive: 2.773%
# Step 15750 | t = 3.15 | alive: 2.400%
# Step 16500 | t = 3.30 | alive: 2.071%
# Step 17250 | t = 3.45 | alive: 1.778%
# Step 18000 | t = 3.60 | alive: 1.541%
# Step 18750 | t = 3.75 | alive: 1.320%
# Step 19500 | t = 3.90 | alive: 1.152%
# Step 20250 | t = 4.05 | alive: 1.006%
# Step 21000 | t = 4.20 | alive: 0.844%
# Step 21750 | t = 4.35 | alive: 0.717%
# Step 22500 | t = 4.50 | alive: 0.616%
# Step 23250 | t = 4.65 | alive: 0.529%
# Step 24000 | t = 4.80 | alive: 0.468%
# Step 24750 | t = 4.95 | alive: 0.407%
# Step 25500 | t = 5.10 | alive: 0.340%
# Step 26250 | t = 5.25 | alive: 0.288%
# Step 27000 | t = 5.40 | alive: 0.244%
# Step 27750 | t = 5.55 | alive: 0.209%
# Step 28500 | t = 5.70 | alive: 0.174%
# Step 29250 | t = 5.85 | alive: 0.151%
# Step 30000 | t = 6.00 | alive: 0.131%
# Step 30750 | t = 6.15 | alive: 0.108%
# Step 31500 | t = 6.30 | alive: 0.101%
# Step 32250 | t = 6.45 | alive: 0.082%
# Step 33000 | t = 6.60 | alive: 0.079%
# Step 33750 | t = 6.75 | alive: 0.066%
# Step 34500 | t = 6.90 | alive: 0.061%
# Step 35250 | t = 7.05 | alive: 0.053%
# Step 36000 | t = 7.20 | alive: 0.047%
# Step 36750 | t = 7.35 | alive: 0.043%
# Step 37500 | t = 7.50 | alive: 0.035%
# Step 38250 | t = 7.65 | alive: 0.031%
# Step 39000 | t = 7.80 | alive: 0.026%
# Step 39750 | t = 7.95 | alive: 0.023%
# Step 40500 | t = 8.10 | alive: 0.018%
# Step 41250 | t = 8.25 | alive: 0.017%
# Step 42000 | t = 8.40 | alive: 0.014%
# Step 42750 | t = 8.55 | alive: 0.011%
# Step 43500 | t = 8.70 | alive: 0.011%
# Step 44250 | t = 8.85 | alive: 0.009%
# Step 45000 | t = 9.00 | alive: 0.008%
# Step 45750 | t = 9.15 | alive: 0.005%
# Step 46500 | t = 9.30 | alive: 0.005%
# Step 47250 | t = 9.45 | alive: 0.005%
# Step 48000 | t = 9.60 | alive: 0.003%
# Step 48750 | t = 9.75 | alive: 0.003%
# Step 49500 | t = 9.90 | alive: 0.003%
# Step 50250 | t = 10.05 | alive: 0.002%
# Step 51000 | t = 10.20 | alive: 0.002%
# Step 51750 | t = 10.35 | alive: 0.002%
# Step 52500 | t = 10.50 | alive: 0.002%
# Step 53250 | t = 10.65 | alive: 0.002%
# Step 54000 | t = 10.80 | alive: 0.002%
# Step 54750 | t = 10.95 | alive: 0.002%

# %% [markdown]
# ### Starting the training with Adam

# %%
# Training Loop w/ Loss Logging

# prep for best‐model tracking
best_loss       = float("inf")
adam_model_path = "best_adam.pth"
best_epoch = 0
eval_Xb = sample_uniform_ellipse(pool_size) #to evaluate the model

total_history = []
pde_history   = []
data_history  = []

model.train()
for ep in range(1, n_epochs+1):

    opt.zero_grad()

    Xb = sample_uniform_ellipse(batch_size)# → [batch_size,2]

    # PDE residual + loss
    r        = pde_residual(model, Xb, A_np, nu_np, eps_np, forcing = None)
    loss_pde = loss_fn(r)

    # data‐loss (fixed x_data, tau_data)
    tau_pred  = model(x_data).squeeze(-1)
    loss_data = (tau_pred - tau_data).pow(2).mean()

    # Sobolev penalty on the raw NN output
    # h2_reg = empirical_h2_norm(model, Xb)

    # total + backward + step
    loss_total = (torch.exp(-2 * model.log_sigma_pde) * loss_pde
               + torch.exp(-2 * model.log_sigma_data) * loss_data
               #+ lambda_sobolev * h2_reg
               + model.log_sigma_pde
               + model.log_sigma_data
    )

    # 6) backward + step
    loss_total.backward()
    opt.step()
    scheduler.step()

    #eval
    r_eval        = pde_residual(model, eval_Xb, A_np, nu_np, eps_np, forcing = None)  #evaluate the model on the true PDE
    loss_eval     = loss_fn(r_eval).item() #+ lambda_data * loss_data.item()

    if loss_eval < best_loss or ep - best_epoch >= epochs_between_decay * 10 :
        best_loss = loss_eval
        torch.save(model.state_dict(), adam_model_path)
        best_epoch = ep

    # 7) logging & histories
    #total_history.append(loss_total.item())
    total_history.append(loss_total.item() \
                            - (model.log_sigma_pde.detach()\
                            + model.log_sigma_data.detach()).item())
    pde_history.append(loss_pde.item())
    data_history.append(loss_data.item())

    if ep % 100 == 0:
        print(
            f"[ep {ep:4d}/{n_epochs}] "
            f"loss_pde={loss_pde:.2e}  "
            f"loss_data={loss_data:.2e}  "
            #f"h2_reg={h2_reg:.2e}"
        )
    if ep % 500 == 0:
        lr = scheduler.get_last_lr()[0]
        print(f"  → epoch {ep:4d},  lr={lr:.2e}")
# Out:
# [ep  100/5000] loss_pde=6.23e-01  loss_data=2.91e-01
# [ep  200/5000] loss_pde=4.81e-01  loss_data=2.65e-01
# [ep  300/5000] loss_pde=4.50e-01  loss_data=2.55e-01
# [ep  400/5000] loss_pde=3.41e-01  loss_data=2.32e-01
# [ep  500/5000] loss_pde=3.96e-01  loss_data=2.64e-01
#   → epoch  500,  lr=2.51e-04
# [ep  600/5000] loss_pde=4.21e-01  loss_data=2.22e-01
# [ep  700/5000] loss_pde=3.92e-01  loss_data=2.40e-01
# [ep  800/5000] loss_pde=4.15e-01  loss_data=2.31e-01
# [ep  900/5000] loss_pde=3.31e-01  loss_data=2.18e-01
# [ep 1000/5000] loss_pde=3.25e-01  loss_data=2.02e-01
#   → epoch 1000,  lr=1.26e-04
# [ep 1100/5000] loss_pde=4.00e-01  loss_data=1.99e-01
# [ep 1200/5000] loss_pde=3.67e-01  loss_data=1.98e-01
# [ep 1300/5000] loss_pde=3.59e-01  loss_data=2.13e-01
# [ep 1400/5000] loss_pde=3.52e-01  loss_data=2.31e-01
# [ep 1500/5000] loss_pde=3.10e-01  loss_data=2.28e-01
#   → epoch 1500,  lr=6.29e-05
# [ep 1600/5000] loss_pde=3.49e-01  loss_data=2.24e-01
# [ep 1700/5000] loss_pde=3.76e-01  loss_data=2.27e-01
# [ep 1800/5000] loss_pde=4.46e-01  loss_data=2.25e-01
# [ep 1900/5000] loss_pde=4.06e-01  loss_data=2.22e-01
# [ep 2000/5000] loss_pde=2.98e-01  loss_data=2.01e-01
#   → epoch 2000,  lr=3.15e-05
# [ep 2100/5000] loss_pde=3.10e-01  loss_data=2.11e-01
# [ep 2200/5000] loss_pde=4.29e-01  loss_data=2.13e-01
# [ep 2300/5000] loss_pde=3.50e-01  loss_data=2.03e-01
# [ep 2400/5000] loss_pde=3.68e-01  loss_data=2.10e-01
# [ep 2500/5000] loss_pde=4.00e-01  loss_data=2.12e-01
#   → epoch 2500,  lr=1.58e-05
# [ep 2600/5000] loss_pde=4.24e-01  loss_data=2.07e-01
# [ep 2700/5000] loss_pde=4.27e-01  loss_data=2.10e-01
# [ep 2800/5000] loss_pde=3.70e-01  loss_data=2.07e-01
# [ep 2900/5000] loss_pde=3.43e-01  loss_data=2.10e-01
# [ep 3000/5000] loss_pde=3.16e-01  loss_data=2.11e-01
#   → epoch 3000,  lr=7.92e-06
# [ep 3100/5000] loss_pde=4.44e-01  loss_data=2.00e-01
# [ep 3200/5000] loss_pde=2.97e-01  loss_data=2.09e-01
# [ep 3300/5000] loss_pde=3.60e-01  loss_data=2.04e-01
# [ep 3400/5000] loss_pde=4.51e-01  loss_data=2.06e-01
# [ep 3500/5000] loss_pde=3.47e-01  loss_data=2.06e-01
#   → epoch 3500,  lr=3.97e-06
# [ep 3600/5000] loss_pde=4.42e-01  loss_data=2.11e-01
# [ep 3700/5000] loss_pde=2.59e-01  loss_data=2.06e-01
# [ep 3800/5000] loss_pde=4.37e-01  loss_data=2.12e-01
# [ep 3900/5000] loss_pde=3.43e-01  loss_data=2.11e-01
# [ep 4000/5000] loss_pde=4.39e-01  loss_data=2.08e-01
#   → epoch 4000,  lr=1.99e-06
# [ep 4100/5000] loss_pde=4.10e-01  loss_data=2.11e-01
# [ep 4200/5000] loss_pde=3.91e-01  loss_data=2.08e-01
# [ep 4300/5000] loss_pde=4.01e-01  loss_data=2.10e-01
# [ep 4400/5000] loss_pde=5.02e-01  loss_data=2.06e-01
# [ep 4500/5000] loss_pde=4.32e-01  loss_data=2.06e-01
#   → epoch 4500,  lr=9.98e-07
# [ep 4600/5000] loss_pde=3.98e-01  loss_data=2.07e-01
# [ep 4700/5000] loss_pde=2.92e-01  loss_data=2.09e-01
# [ep 4800/5000] loss_pde=3.57e-01  loss_data=2.09e-01
# [ep 4900/5000] loss_pde=3.56e-01  loss_data=2.09e-01
# [ep 5000/5000] loss_pde=4.94e-01  loss_data=2.10e-01
#   → epoch 5000,  lr=5.00e-07

# %% [markdown]
# ### L-BFGS Fine Tuning

# %%
#LBFGS fine-tuning

# Reload best Adam snapshot
print(f"\nLoading best Adam model (loss={best_loss:.3e}, epoch={best_epoch}) …")
model.load_state_dict(torch.load(adam_model_path))
model.to(device)


# define L-BFGS parameters
lbfgs = torch.optim.LBFGS(
    model.parameters(),
    lr=1.0,
    max_iter= 2*n_epochs,
    history_size=500,
    tolerance_grad = 0,
    tolerance_change = 0,
    line_search_fn="strong_wolfe"
)

max_eval = lbfgs.defaults.get('max_eval')

# freeze one big PDE batch for the closure
Xb_ft = sample_uniform_ellipse(pool_size)

lbfgs_total = []
lbfgs_pde   = []
lbfgs_data  = []

#closure function
def closure():
    closure.calls += 1
    lbfgs.zero_grad()
    # PDE term
    r_ft    = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing = None)
    pde_l   = loss_fn(r_ft)

    # data term
    tau_p   = model(x_data).squeeze(-1)
    data_l  = (tau_p - tau_data).pow(2).mean()

    #h2_reg =  empirical_h2_norm(model, Xb_ft)

    #total_l = pde_l + lambda_data * data_l
    total_l = (torch.exp(-2 * model.log_sigma_pde) * pde_l
            + torch.exp(-2 * model.log_sigma_data) * data_l
            #+ lambda_sobolev * h2_reg
            + model.log_sigma_pde
            + model.log_sigma_data
    )
    # record
    #lbfgs_total.append(total_l.item())
    lbfgs_total.append(total_l.item() - \
            (model.log_sigma_pde.detach() + model.log_sigma_data).item())
    lbfgs_pde.append(pde_l.item())
    lbfgs_data.append(data_l.item())

    total_l.backward()

    PRINT_EVERY = 100
    if closure.calls % PRINT_EVERY == 0:
        print(
            f"eval {closure.calls}/{max_eval} | "
            f"loss pde {pde_l:.2e} | "
            f"loss data {data_l:.2e}"
        )
    return total_l

closure.calls = 0
# Out:
# Loading best Adam model (loss=3.574e-01, epoch=5000) …

# %%
# report losses before/after lbfgs
# make sure model is in eval mode so e.g. Dropout/BatchNorm won’t move
model.eval()

# PDE loss
r_before = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing = None)
before_pde = loss_fn(r_before).item()

# empirical Sobolev norm
#before_h2 = empirical_h2_norm(model, Xb_ft).item()

# data loss (doesn't need grads)
with torch.no_grad():
    tau_p       = model(x_data).squeeze(-1)
    before_data = (tau_p - tau_data).pow(2).mean()

print(f"Before L-BFGS → PDE {before_pde:.3e}, DATA {before_data:.3e}")#, SOBOLEV {before_h2:.2e})

# running L-BFGS
print("→ Running L-BFGS...")
loss_after = lbfgs.step(closure)
print(f"L-BFGS did {closure.calls} closure calls, final total loss = {loss_after:.2e}")
# Out:
# Before L-BFGS → PDE 3.817e-01, DATA 2.097e-01
# → Running L-BFGS...
# eval 100/12500 | loss pde 1.79e+00 | loss data 3.54e-03
# eval 200/12500 | loss pde 1.21e+00 | loss data 2.56e-03
# eval 300/12500 | loss pde 6.76e-01 | loss data 2.65e-03
# eval 400/12500 | loss pde 3.88e-01 | loss data 2.51e-03
# eval 500/12500 | loss pde 2.00e-01 | loss data 2.51e-03
# eval 600/12500 | loss pde 1.20e-01 | loss data 2.60e-03
# eval 700/12500 | loss pde 8.18e-02 | loss data 2.63e-03
# eval 800/12500 | loss pde 5.58e-02 | loss data 2.61e-03
# eval 900/12500 | loss pde 4.18e-02 | loss data 2.65e-03
# eval 1000/12500 | loss pde 3.23e-02 | loss data 2.75e-03
# eval 1100/12500 | loss pde 2.72e-02 | loss data 2.72e-03
# eval 1200/12500 | loss pde 2.22e-02 | loss data 2.78e-03
# eval 1300/12500 | loss pde 1.91e-02 | loss data 2.77e-03
# eval 1400/12500 | loss pde 1.65e-02 | loss data 2.80e-03
# eval 1500/12500 | loss pde 1.44e-02 | loss data 2.81e-03
# eval 1600/12500 | loss pde 1.23e-02 | loss data 2.87e-03
# eval 1700/12500 | loss pde 1.07e-02 | loss data 2.94e-03
# eval 1800/12500 | loss pde 9.58e-03 | loss data 2.90e-03
# eval 1900/12500 | loss pde 8.47e-03 | loss data 2.94e-03
# eval 2000/12500 | loss pde 7.92e-03 | loss data 2.88e-03
# eval 2100/12500 | loss pde 7.49e-03 | loss data 2.73e-03
# eval 2200/12500 | loss pde 6.99e-03 | loss data 2.60e-03
# eval 2300/12500 | loss pde 6.05e-03 | loss data 2.56e-03
# eval 2400/12500 | loss pde 5.47e-03 | loss data 2.54e-03
# eval 2500/12500 | loss pde 4.79e-03 | loss data 2.55e-03
# eval 2600/12500 | loss pde 4.15e-03 | loss data 2.51e-03
# eval 2700/12500 | loss pde 3.77e-03 | loss data 2.45e-03
# eval 2800/12500 | loss pde 3.19e-03 | loss data 2.47e-03
# eval 2900/12500 | loss pde 2.75e-03 | loss data 2.51e-03
# eval 3000/12500 | loss pde 2.43e-03 | loss data 2.52e-03
# eval 3100/12500 | loss pde 2.17e-03 | loss data 2.54e-03
# eval 3200/12500 | loss pde 2.02e-03 | loss data 2.52e-03
# eval 3300/12500 | loss pde 1.78e-03 | loss data 2.56e-03
# eval 3400/12500 | loss pde 1.64e-03 | loss data 2.53e-03
# eval 3500/12500 | loss pde 1.50e-03 | loss data 2.56e-03
# eval 3600/12500 | loss pde 1.42e-03 | loss data 2.53e-03
# eval 3700/12500 | loss pde 1.32e-03 | loss data 2.51e-03
# eval 3800/12500 | loss pde 1.21e-03 | loss data 2.51e-03
# eval 3900/12500 | loss pde 1.13e-03 | loss data 2.53e-03
# eval 4000/12500 | loss pde 1.04e-03 | loss data 2.52e-03
# eval 4100/12500 | loss pde 9.61e-04 | loss data 2.51e-03
# eval 4200/12500 | loss pde 8.98e-04 | loss data 2.52e-03
# eval 4300/12500 | loss pde 8.40e-04 | loss data 2.53e-03
# eval 4400/12500 | loss pde 8.01e-04 | loss data 2.50e-03
# eval 4500/12500 | loss pde 7.35e-04 | loss data 2.53e-03
# eval 4600/12500 | loss pde 6.87e-04 | loss data 2.54e-03
# eval 4700/12500 | loss pde 6.50e-04 | loss data 2.52e-03
# eval 4800/12500 | loss pde 6.13e-04 | loss data 2.53e-03
# eval 4900/12500 | loss pde 5.76e-04 | loss data 2.49e-03
# eval 5000/12500 | loss pde 5.54e-04 | loss data 2.45e-03
# eval 5100/12500 | loss pde 5.02e-04 | loss data 2.49e-03
# eval 5200/12500 | loss pde 4.85e-04 | loss data 2.47e-03
# eval 5300/12500 | loss pde 4.60e-04 | loss data 2.47e-03
# eval 5400/12500 | loss pde 4.31e-04 | loss data 2.47e-03
# eval 5500/12500 | loss pde 4.13e-04 | loss data 2.47e-03
# eval 5600/12500 | loss pde 3.90e-04 | loss data 2.45e-03
# eval 5700/12500 | loss pde 3.79e-04 | loss data 2.43e-03
# eval 5800/12500 | loss pde 3.59e-04 | loss data 2.44e-03
# eval 5900/12500 | loss pde 3.43e-04 | loss data 2.44e-03
# eval 6000/12500 | loss pde 3.19e-04 | loss data 2.46e-03
# eval 6100/12500 | loss pde 3.05e-04 | loss data 2.47e-03
# eval 6200/12500 | loss pde 2.88e-04 | loss data 2.45e-03
# eval 6300/12500 | loss pde 2.76e-04 | loss data 2.46e-03
# eval 6400/12500 | loss pde 2.61e-04 | loss data 2.48e-03
# eval 6500/12500 | loss pde 2.50e-04 | loss data 2.47e-03
# eval 6600/12500 | loss pde 2.41e-04 | loss data 2.46e-03
# eval 6700/12500 | loss pde 2.34e-04 | loss data 2.45e-03
# eval 6800/12500 | loss pde 2.26e-04 | loss data 2.46e-03
# eval 6900/12500 | loss pde 2.18e-04 | loss data 2.45e-03
# eval 7000/12500 | loss pde 2.10e-04 | loss data 2.45e-03
# eval 7100/12500 | loss pde 2.02e-04 | loss data 2.44e-03
# eval 7200/12500 | loss pde 1.98e-04 | loss data 2.43e-03
# eval 7300/12500 | loss pde 1.92e-04 | loss data 2.43e-03
# eval 7400/12500 | loss pde 1.85e-04 | loss data 2.43e-03
# eval 7500/12500 | loss pde 1.79e-04 | loss data 2.43e-03
# eval 7600/12500 | loss pde 1.73e-04 | loss data 2.43e-03
# eval 7700/12500 | loss pde 1.68e-04 | loss data 2.42e-03
# eval 7800/12500 | loss pde 1.60e-04 | loss data 2.42e-03
# eval 7900/12500 | loss pde 1.54e-04 | loss data 2.42e-03
# eval 8000/12500 | loss pde 1.51e-04 | loss data 2.42e-03
# eval 8100/12500 | loss pde 1.44e-04 | loss data 2.42e-03
# eval 8200/12500 | loss pde 1.41e-04 | loss data 2.43e-03
# eval 8300/12500 | loss pde 1.36e-04 | loss data 2.42e-03
# eval 8400/12500 | loss pde 1.32e-04 | loss data 2.41e-03
# eval 8500/12500 | loss pde 1.30e-04 | loss data 2.41e-03
# eval 8600/12500 | loss pde 1.27e-04 | loss data 2.40e-03
# eval 8700/12500 | loss pde 1.24e-04 | loss data 2.39e-03
# eval 8800/12500 | loss pde 1.21e-04 | loss data 2.38e-03
# eval 8900/12500 | loss pde 1.17e-04 | loss data 2.38e-03
# eval 9000/12500 | loss pde 1.14e-04 | loss data 2.37e-03
# eval 9100/12500 | loss pde 1.11e-04 | loss data 2.37e-03
# eval 9200/12500 | loss pde 1.09e-04 | loss data 2.36e-03
# eval 9300/12500 | loss pde 1.06e-04 | loss data 2.35e-03
# eval 9400/12500 | loss pde 1.03e-04 | loss data 2.35e-03
# eval 9500/12500 | loss pde 9.99e-05 | loss data 2.35e-03
# eval 9600/12500 | loss pde 9.79e-05 | loss data 2.34e-03
# eval 9700/12500 | loss pde 9.63e-05 | loss data 2.35e-03
# eval 9800/12500 | loss pde 9.44e-05 | loss data 2.35e-03
# eval 9900/12500 | loss pde 9.25e-05 | loss data 2.34e-03
# eval 10000/12500 | loss pde 9.04e-05 | loss data 2.35e-03
# eval 10100/12500 | loss pde 8.83e-05 | loss data 2.35e-03
# L-BFGS did 10162 closure calls, final total loss = 4.85e-01

# %%
# after L-BFGS, same pattern:
model.eval()
r_after = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing = None)
after_pde = loss_fn(r_after).item()
#after_h2 = empirical_h2_norm(model, Xb_ft).item()
with torch.no_grad():
    tau_p       = model(x_data).squeeze(-1)
    after_data = (tau_p - tau_data).pow(2).mean()
print(f" After L-BFGS → PDE {after_pde:.3e}, DATA {after_data:.3e}")

# saving the L-BFGS fine-tuned model
lbfgs_model_path = 'lbfgs_finetuned.pth'
torch.save(model.state_dict(), lbfgs_model_path)
# Out:
#  After L-BFGS → PDE 8.798e-05, DATA 2.344e-03

# %% [markdown]
# ### ENGD Fine Tuning

# %%
# Loading the post LBFGS model
print(f"\nLoading post L-BFGS model (losses: TOTAL={loss_after:.2e}, PDE={after_pde:.2e}, DATA {after_data:.2e})")
model.load_state_dict(torch.load(lbfgs_model_path))
model.to(device)

# Reuse same PDE batch as L-BFGS
Xb_ft = sample_uniform_ellipse(pool_size)
Xb_ft.requires_grad_(True)

# Logging
engd_total = []
engd_pde   = []
engd_data  = []

# Parameter shapes for HVP
param_shapes = [p.shape for p in model.parameters() if p.requires_grad]
# Out:
# Loading post L-BFGS model (losses: TOTAL=4.85e-01, PDE=8.80e-05, DATA 2.34e-03)

# %%
# ENGD loop hyperparameters
engd_steps = n_epochs//2
cg_maxiter = 10
cg_tol = 1e-3

# Damping hyperparameters (minimal and adaptive)
base_damping = 1e-3  # Small starting value per step
damping = base_damping  # Current value
max_damping_tries = 5  # Allow more tries for finer minimal λ
max_damping = 1e1  # Cap to prevent excessive increase
min_damping = 1e-7
damping_reduction = 0.7  # times damping_reduction after success

# Line search hyperparameters
initial_alpha = 1.0
rho = 0.1
c = 1e-2
max_ls_iters = 20
min_alpha = 1e-10
fallback_lr = 5e-7
prev_alpha = initial_alpha

# Verbosity level: 0=minimal, 1=moderate, 2=full diagnostics
verbose = 0

for step in range(1, engd_steps + 1):
    model.zero_grad()

    # Compute losses and total_l
    r = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing=None)
    pde_l = loss_fn(r)
    tau_p = model(x_data).squeeze(-1)
    data_l = (tau_p - tau_data).pow(2).mean()
    total_l = (torch.exp(-2 * model.log_sigma_pde) * pde_l +
               torch.exp(-2 * model.log_sigma_data) * data_l +
               model.log_sigma_pde + model.log_sigma_data)

    # Compute excluded for logging
    excluded_total = (torch.exp(-2 * model.log_sigma_pde) * pde_l +
                      torch.exp(-2 * model.log_sigma_data) * data_l).item()

    # Logging
    engd_total.append(excluded_total)
    engd_pde.append(pde_l.item())
    engd_data.append(data_l.item())

    # Optional pre-update log (sparse)
    if verbose >= 1 or step % 10 == 0:
        print(f"ENGD step {step}: Pre-update full ℒ={total_l.item():.2e}, excluded={excluded_total:.2e}")

    # Backward
    total_l.backward()
    g_flat = torch.cat([p.grad.view(-1) for p in model.parameters() if p.grad is not None])
    g_norm = torch.norm(g_flat).item()

    # CG solve with minimal adaptive damping (reset to base each step)
    damping = base_damping  # Reset to small value
    direction_dot = 0  # Initialize
    for damping_try in range(max_damping_tries):
        s = torch.zeros_like(g_flat)
        r_cg = -g_flat.clone()
        p_cg = r_cg.clone()
        rs_old = torch.dot(r_cg, r_cg)
        rs_new = rs_old

        for cg_iter in range(cg_maxiter):
            Ap = energy_hvp(p_cg) + damping * p_cg
            alpha_cg = rs_old / (torch.dot(p_cg, Ap) + 1e-12)
            s += alpha_cg * p_cg
            r_cg -= alpha_cg * Ap
            rs_new = torch.dot(r_cg, r_cg)
            if torch.sqrt(rs_new) < cg_tol * torch.sqrt(rs_old):
                break
            p_cg = r_cg + (rs_new / rs_old) * p_cg
            rs_old = rs_new

        s_norm = torch.norm(s).item()

        direction_dot = torch.dot(g_flat, s)
        if direction_dot < 0 and damping <= max_damping:
            if verbose >= 1:
                print(f"ENGD step {step}: Found good direction with damping={damping:.2e} (tries={damping_try+1})")
            break
        else:
            damping *= 2  # Increase for next try
            if damping > max_damping:
                break
            if verbose >= 1:
                print(f"ENGD step {step}: Bad direction (dot(g,s)={direction_dot:.2e}). Increasing damping to {damping:.2e} and retrying CG (try {damping_try+2}).")

    if direction_dot >= 0:
        if verbose >= 1:
            print(f"ENGD [{step:3d}/{engd_steps}] | Failed to find descent direction after {max_damping_tries} tries (final damping={damping:.2e}). Skipping update.")
        continue

    # Line search
    params = list(model.parameters())
    backup = [p.data.clone() for p in params]

    alpha = prev_alpha
    found = False
    for ls_iter in range(max_ls_iters):
        offset = 0
        for i, p in enumerate(params):
            numel = p.numel()
            trial = backup[i] + alpha * s[offset:offset + numel].reshape(backup[i].shape)
            p.data.copy_(trial)
            offset += numel

        r_trial = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing=None)
        pde_l_trial = loss_fn(r_trial)
        tau_p_trial = model(x_data).squeeze(-1)
        data_l_trial = (tau_p_trial - tau_data).pow(2).mean()
        total_l_trial = (torch.exp(-2 * model.log_sigma_pde) * pde_l_trial +
                         torch.exp(-2 * model.log_sigma_data) * data_l_trial +
                         model.log_sigma_pde + model.log_sigma_data)

        armijo_threshold = total_l + c * alpha * direction_dot
        improvement = total_l_trial <= armijo_threshold + 1e-12

        # Diagnostic print (controlled by verbose)
        if verbose == 2 or (verbose == 1 and (ls_iter % 5 == 0 or ls_iter == max_ls_iters - 1)):
            print(f"ENGD step {step}: LS iter {ls_iter+1}: alpha={alpha:.2e}, trial_loss={total_l_trial.item():.2e}, "
                  f"threshold={armijo_threshold.item():.2e}, dot(g,s)={direction_dot:.2e}, improvement={improvement}")

        if improvement:
            found = True
            prev_alpha = alpha *  1.5#min(alpha * 1.5, 1.0)
            break

        alpha *= rho
        if alpha < min_alpha:
            if verbose >= 1:
                print(f"ENGD step {step}: LS: Alpha too small ({alpha:.2e} < {min_alpha:.2e}). Stopping search.")
            break

    if found:
        # Update applied; compute post-update for sparse logging
        total_l_post = total_l_trial.item()  # Reuse from last trial
        excluded_total_post = (torch.exp(-2 * model.log_sigma_pde) * pde_l_trial +
                               torch.exp(-2 * model.log_sigma_data) * data_l_trial).item()

        # Adaptively reduce base for next step after success
        base_damping = max(base_damping * damping_reduction, min_damping)  # Halve, with floor
        if verbose >= 1 or step % 10 == 0:
            print(f"ENGD step {step}: Post-update full ℒ={total_l_post:.2e}, excluded={excluded_total_post:.2e}")
    else:
        # Fallback
        for i, p in enumerate(params):
            p.data.copy_(backup[i])
        offset = 0
        for i, p in enumerate(params):
            numel = p.numel()
            p.data.add_(fallback_lr * s[offset:offset + numel].view_as(p))
            offset += numel
        if verbose >= 1:
            print(f"ENGD [{step:3d}/{engd_steps}] | Line search failed. Applied fallback (lr={fallback_lr:.2e}).")

    # Main print (every 25 or last)
    if step % 25 == 0 or step == engd_steps:
        print(f"ENGD [{step:3d}/{engd_steps}] | "
              f"Total {engd_total[-1]:.2e} | PDE {pde_l:.2e} | Data {data_l:.2e} | "
              f"Alpha {alpha:.2e} | Damping {damping:.2e}"
              f"\npre-CG ||g|| = {g_norm:.2e}, post-CG ||s|| = {s_norm:.2e}, rs_new = {rs_new:.2e} (CG iters: {cg_iter + 1})"
              )
# Out:
# ENGD step 10: Pre-update full ℒ=-5.06e+00, excluded=1.95e+00
# ENGD step 10: Post-update full ℒ=-5.07e+00, excluded=1.94e+00
# ENGD step 20: Pre-update full ℒ=-5.20e+00, excluded=1.80e+00
# ENGD step 20: Post-update full ℒ=-5.21e+00, excluded=1.80e+00
# ENGD [ 25/2500] | Total 1.78e+00 | PDE 2.24e-04 | Data 2.35e-03 | Alpha 1.68e+00 | Damping 1.92e-07
# pre-CG ||g|| = 7.07e+01, post-CG ||s|| = 3.10e-04, rs_new = 3.10e+03 (CG iters: 10)
# ENGD step 30: Pre-update full ℒ=-5.25e+00, excluded=1.76e+00
# ENGD step 30: Post-update full ℒ=-5.26e+00, excluded=1.75e+00
# ENGD step 40: Pre-update full ℒ=-5.29e+00, excluded=1.72e+00
# ENGD step 40: Post-update full ℒ=-5.29e+00, excluded=1.71e+00
# ENGD step 50: Pre-update full ℒ=-5.32e+00, excluded=1.69e+00
# ENGD step 50: Post-update full ℒ=-5.32e+00, excluded=1.69e+00
# ENGD [ 50/2500] | Total 1.69e+00 | PDE 2.09e-04 | Data 2.35e-03 | Alpha 4.25e-01 | Damping 1.00e-07
# pre-CG ||g|| = 6.69e+01, post-CG ||s|| = 2.19e-04, rs_new = 1.35e+03 (CG iters: 10)
# ENGD step 60: Pre-update full ℒ=-5.34e+00, excluded=1.66e+00
# ENGD step 60: Post-update full ℒ=-5.35e+00, excluded=1.66e+00
# ENGD step 70: Pre-update full ℒ=-5.37e+00, excluded=1.64e+00
# ENGD step 70: Post-update full ℒ=-5.37e+00, excluded=1.64e+00
# ENGD [ 75/2500] | Total 1.63e+00 | PDE 1.99e-04 | Data 2.35e-03 | Alpha 1.07e+00 | Damping 1.00e-07
# pre-CG ||g|| = 3.16e+01, post-CG ||s|| = 3.64e-04, rs_new = 2.64e+03 (CG iters: 10)
# ENGD step 80: Pre-update full ℒ=-5.38e+00, excluded=1.62e+00
# ENGD step 80: Post-update full ℒ=-5.39e+00, excluded=1.62e+00
# ENGD step 90: Pre-update full ℒ=-5.40e+00, excluded=1.61e+00
# ENGD step 90: Post-update full ℒ=-5.40e+00, excluded=1.60e+00
# ENGD step 100: Pre-update full ℒ=-5.42e+00, excluded=1.59e+00
# ENGD step 100: Post-update full ℒ=-5.42e+00, excluded=1.59e+00
# ENGD [100/2500] | Total 1.59e+00 | PDE 1.91e-04 | Data 2.35e-03 | Alpha 2.71e-01 | Damping 1.00e-07
# pre-CG ||g|| = 6.31e+01, post-CG ||s|| = 1.69e-04, rs_new = 6.18e+02 (CG iters: 10)
# ENGD step 110: Pre-update full ℒ=-5.43e+00, excluded=1.57e+00
# ENGD step 110: Post-update full ℒ=-5.43e+00, excluded=1.57e+00
# ENGD step 120: Pre-update full ℒ=-5.44e+00, excluded=1.56e+00
# ENGD step 120: Post-update full ℒ=-5.45e+00, excluded=1.56e+00
# ENGD [125/2500] | Total 1.55e+00 | PDE 1.85e-04 | Data 2.36e-03 | Alpha 6.84e-01 | Damping 1.00e-07
# pre-CG ||g|| = 2.74e+01, post-CG ||s|| = 1.71e-04, rs_new = 8.74e+02 (CG iters: 10)
# ENGD step 130: Pre-update full ℒ=-5.46e+00, excluded=1.55e+00
# ENGD step 130: Post-update full ℒ=-5.46e+00, excluded=1.55e+00
# ENGD step 140: Pre-update full ℒ=-5.47e+00, excluded=1.54e+00
# ENGD step 140: Post-update full ℒ=-5.47e+00, excluded=1.54e+00
# ENGD step 150: Pre-update full ℒ=-5.49e+00, excluded=1.51e+00
# ENGD step 150: Post-update full ℒ=-5.49e+00, excluded=1.51e+00
# ENGD [150/2500] | Total 1.51e+00 | PDE 1.78e-04 | Data 2.36e-03 | Alpha 1.73e+00 | Damping 1.00e-07
# pre-CG ||g|| = 2.34e+01, post-CG ||s|| = 1.35e-04, rs_new = 5.86e+02 (CG iters: 10)
# ENGD step 160: Pre-update full ℒ=-5.50e+00, excluded=1.50e+00
# ENGD step 160: Post-update full ℒ=-5.50e+00, excluded=1.50e+00
# ENGD step 170: Pre-update full ℒ=-5.50e+00, excluded=1.50e+00
# ENGD step 170: Post-update full ℒ=-5.51e+00, excluded=1.50e+00
# ENGD [175/2500] | Total 1.50e+00 | PDE 1.75e-04 | Data 2.36e-03 | Alpha 4.36e-01 | Damping 1.00e-07
# pre-CG ||g|| = 3.21e+01, post-CG ||s|| = 1.02e-04, rs_new = 3.07e+02 (CG iters: 10)
# ENGD step 180: Pre-update full ℒ=-5.51e+00, excluded=1.49e+00
# ENGD step 180: Post-update full ℒ=-5.51e+00, excluded=1.49e+00
# ENGD step 190: Pre-update full ℒ=-5.52e+00, excluded=1.49e+00
# ENGD step 190: Post-update full ℒ=-5.52e+00, excluded=1.49e+00
# ENGD step 200: Pre-update full ℒ=-5.52e+00, excluded=1.48e+00
# ENGD step 200: Post-update full ℒ=-5.52e+00, excluded=1.48e+00
# ENGD [200/2500] | Total 1.48e+00 | PDE 1.73e-04 | Data 2.36e-03 | Alpha 1.10e+00 | Damping 1.00e-07
# pre-CG ||g|| = 1.78e+01, post-CG ||s|| = 1.51e-04, rs_new = 5.74e+02 (CG iters: 10)
# ENGD step 210: Pre-update full ℒ=-5.53e+00, excluded=1.48e+00
# ENGD step 210: Post-update full ℒ=-5.53e+00, excluded=1.48e+00
# ENGD step 220: Pre-update full ℒ=-5.53e+00, excluded=1.47e+00
# ENGD step 220: Post-update full ℒ=-5.53e+00, excluded=1.47e+00
# ENGD [225/2500] | Total 1.47e+00 | PDE 1.71e-04 | Data 2.36e-03 | Alpha 2.78e-01 | Damping 1.00e-07
# pre-CG ||g|| = 3.67e+01, post-CG ||s|| = 9.71e-05, rs_new = 2.04e+02 (CG iters: 10)
# ENGD step 230: Pre-update full ℒ=-5.54e+00, excluded=1.47e+00
# ENGD step 230: Post-update full ℒ=-5.54e+00, excluded=1.47e+00
# ENGD step 240: Pre-update full ℒ=-5.54e+00, excluded=1.46e+00
# ENGD step 240: Post-update full ℒ=-5.54e+00, excluded=1.46e+00
# ENGD step 250: Pre-update full ℒ=-5.54e+00, excluded=1.46e+00
# ENGD step 250: Post-update full ℒ=-5.54e+00, excluded=1.46e+00
# ENGD [250/2500] | Total 1.46e+00 | PDE 1.69e-04 | Data 2.36e-03 | Alpha 7.03e-01 | Damping 1.00e-07
# pre-CG ||g|| = 1.73e+01, post-CG ||s|| = 1.03e-04, rs_new = 3.28e+02 (CG iters: 10)
# ENGD step 260: Pre-update full ℒ=-5.55e+00, excluded=1.45e+00
# ENGD step 260: Post-update full ℒ=-5.55e+00, excluded=1.45e+00
# ENGD step 270: Pre-update full ℒ=-5.55e+00, excluded=1.45e+00
# ENGD step 270: Post-update full ℒ=-5.55e+00, excluded=1.45e+00
# ENGD [275/2500] | Total 1.45e+00 | PDE 1.67e-04 | Data 2.37e-03 | Alpha 1.77e+00 | Damping 1.00e-07
# pre-CG ||g|| = 1.59e+01, post-CG ||s|| = 9.78e-05, rs_new = 2.89e+02 (CG iters: 10)
# ENGD step 280: Pre-update full ℒ=-5.56e+00, excluded=1.44e+00
# ENGD step 280: Post-update full ℒ=-5.56e+00, excluded=1.44e+00
# ENGD step 290: Pre-update full ℒ=-5.56e+00, excluded=1.44e+00
# ENGD step 290: Post-update full ℒ=-5.56e+00, excluded=1.44e+00
# ENGD step 300: Pre-update full ℒ=-5.56e+00, excluded=1.44e+00
# ENGD step 300: Post-update full ℒ=-5.57e+00, excluded=1.44e+00
# ENGD [300/2500] | Total 1.44e+00 | PDE 1.65e-04 | Data 2.37e-03 | Alpha 4.48e-01 | Damping 1.00e-07
# pre-CG ||g|| = 1.15e+01, post-CG ||s|| = 4.24e-04, rs_new = 1.33e+03 (CG iters: 10)
# ENGD step 310: Pre-update full ℒ=-5.58e+00, excluded=1.43e+00
# ENGD step 310: Post-update full ℒ=-5.58e+00, excluded=1.43e+00
# ENGD step 320: Pre-update full ℒ=-5.58e+00, excluded=1.42e+00
# ENGD step 320: Post-update full ℒ=-5.58e+00, excluded=1.42e+00
# ENGD [325/2500] | Total 1.42e+00 | PDE 1.63e-04 | Data 2.37e-03 | Alpha 1.13e+00 | Damping 1.00e-07
# pre-CG ||g|| = 1.32e+01, post-CG ||s|| = 8.78e-05, rs_new = 2.24e+02 (CG iters: 10)
# ENGD step 330: Pre-update full ℒ=-5.58e+00, excluded=1.42e+00
# ENGD step 330: Post-update full ℒ=-5.58e+00, excluded=1.42e+00
# ENGD step 340: Pre-update full ℒ=-5.58e+00, excluded=1.42e+00
# ENGD step 340: Post-update full ℒ=-5.58e+00, excluded=1.42e+00
# ENGD step 350: Pre-update full ℒ=-5.58e+00, excluded=1.42e+00
# ENGD step 350: Post-update full ℒ=-5.59e+00, excluded=1.42e+00
# ENGD [350/2500] | Total 1.42e+00 | PDE 1.62e-04 | Data 2.37e-03 | Alpha 2.86e-01 | Damping 1.00e-07
# pre-CG ||g|| = 2.70e+01, post-CG ||s|| = 7.05e-05, rs_new = 1.04e+02 (CG iters: 10)
# ENGD step 360: Pre-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD step 360: Post-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD step 370: Pre-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD step 370: Post-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD [375/2500] | Total 1.41e+00 | PDE 1.61e-04 | Data 2.37e-03 | Alpha 7.21e-01 | Damping 1.00e-07
# pre-CG ||g|| = 1.21e+01, post-CG ||s|| = 8.49e-05, rs_new = 2.03e+02 (CG iters: 10)
# ENGD step 380: Pre-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD step 380: Post-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD step 390: Pre-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD step 390: Post-update full ℒ=-5.59e+00, excluded=1.41e+00
# ENGD step 400: Pre-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD step 400: Post-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD [400/2500] | Total 1.40e+00 | PDE 1.60e-04 | Data 2.37e-03 | Alpha 1.82e+00 | Damping 1.00e-07
# pre-CG ||g|| = 1.36e+01, post-CG ||s|| = 6.48e-05, rs_new = 1.38e+02 (CG iters: 10)
# ENGD step 410: Pre-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD step 410: Post-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD step 420: Pre-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD step 420: Post-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD [425/2500] | Total 1.40e+00 | PDE 1.59e-04 | Data 2.37e-03 | Alpha 4.60e-01 | Damping 1.00e-07
# pre-CG ||g|| = 9.17e+00, post-CG ||s|| = 2.38e-04, rs_new = 5.78e+02 (CG iters: 10)
# ENGD step 430: Pre-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD step 430: Post-update full ℒ=-5.60e+00, excluded=1.40e+00
# ENGD step 440: Pre-update full ℒ=-5.60e+00, excluded=1.39e+00
# ENGD step 440: Post-update full ℒ=-5.61e+00, excluded=1.39e+00
# ENGD step 450: Pre-update full ℒ=-5.61e+00, excluded=1.39e+00
# ENGD step 450: Post-update full ℒ=-5.61e+00, excluded=1.39e+00
# ENGD [450/2500] | Total 1.39e+00 | PDE 1.58e-04 | Data 2.37e-03 | Alpha 1.16e+00 | Damping 1.00e-07
# pre-CG ||g|| = 1.42e+01, post-CG ||s|| = 5.57e-05, rs_new = 1.02e+02 (CG iters: 10)
# ENGD step 460: Pre-update full ℒ=-5.61e+00, excluded=1.39e+00
# ENGD step 460: Post-update full ℒ=-5.61e+00, excluded=1.39e+00
# ENGD step 470: Pre-update full ℒ=-5.63e+00, excluded=1.37e+00
# ENGD step 470: Post-update full ℒ=-5.63e+00, excluded=1.37e+00
# ENGD [475/2500] | Total 1.36e+00 | PDE 1.53e-04 | Data 2.38e-03 | Alpha 2.93e-01 | Damping 1.00e-07
# pre-CG ||g|| = 4.29e+01, post-CG ||s|| = 7.10e-05, rs_new = 4.81e+01 (CG iters: 10)
# ENGD step 480: Pre-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD step 480: Post-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD step 490: Pre-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD step 490: Post-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD step 500: Pre-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD step 500: Post-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD [500/2500] | Total 1.36e+00 | PDE 1.52e-04 | Data 2.38e-03 | Alpha 7.41e-01 | Damping 1.00e-07
# pre-CG ||g|| = 7.05e+00, post-CG ||s|| = 8.36e-05, rs_new = 2.16e+02 (CG iters: 10)
# ENGD step 510: Pre-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD step 510: Post-update full ℒ=-5.64e+00, excluded=1.36e+00
# ENGD step 520: Pre-update full ℒ=-5.64e+00, excluded=1.35e+00
# ENGD step 520: Post-update full ℒ=-5.64e+00, excluded=1.35e+00
# ENGD [525/2500] | Total 1.35e+00 | PDE 1.52e-04 | Data 2.38e-03 | Alpha 1.87e+00 | Damping 1.00e-07
# pre-CG ||g|| = 1.67e+01, post-CG ||s|| = 5.36e-05, rs_new = 6.22e+01 (CG iters: 10)
# ENGD step 530: Pre-update full ℒ=-5.64e+00, excluded=1.35e+00
# ENGD step 530: Post-update full ℒ=-5.64e+00, excluded=1.35e+00
# ENGD step 540: Pre-update full ℒ=-5.64e+00, excluded=1.35e+00
# ENGD step 540: Post-update full ℒ=-5.64e+00, excluded=1.35e+00
# ENGD step 550: Pre-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD step 550: Post-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD [550/2500] | Total 1.35e+00 | PDE 1.51e-04 | Data 2.38e-03 | Alpha 4.72e-01 | Damping 1.00e-07
# pre-CG ||g|| = 6.66e+00, post-CG ||s|| = 1.53e-04, rs_new = 2.54e+02 (CG iters: 10)
# ENGD step 560: Pre-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD step 560: Post-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD step 570: Pre-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD step 570: Post-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD [575/2500] | Total 1.35e+00 | PDE 1.51e-04 | Data 2.38e-03 | Alpha 1.19e+00 | Damping 1.00e-07
# pre-CG ||g|| = 1.42e+01, post-CG ||s|| = 4.26e-05, rs_new = 4.45e+01 (CG iters: 10)
# ENGD step 580: Pre-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD step 580: Post-update full ℒ=-5.65e+00, excluded=1.35e+00
# ENGD step 590: Pre-update full ℒ=-5.65e+00, excluded=1.34e+00
# ENGD step 590: Post-update full ℒ=-5.65e+00, excluded=1.34e+00
# ENGD step 600: Pre-update full ℒ=-5.65e+00, excluded=1.34e+00
# ENGD step 600: Post-update full ℒ=-5.65e+00, excluded=1.34e+00
# ENGD [600/2500] | Total 1.34e+00 | PDE 1.50e-04 | Data 2.38e-03 | Alpha 3.01e-01 | Damping 1.00e-07
# pre-CG ||g|| = 8.15e+00, post-CG ||s|| = 5.10e-05, rs_new = 7.43e+01 (CG iters: 10)
# ENGD step 610: Pre-update full ℒ=-5.70e+00, excluded=1.29e+00
# ENGD step 610: Post-update full ℒ=-5.70e+00, excluded=1.29e+00
# ENGD step 620: Pre-update full ℒ=-5.70e+00, excluded=1.29e+00
# ENGD step 620: Post-update full ℒ=-5.70e+00, excluded=1.29e+00
# ENGD [625/2500] | Total 1.29e+00 | PDE 1.41e-04 | Data 2.40e-03 | Alpha 7.60e-01 | Damping 1.00e-07
# pre-CG ||g|| = 3.99e+00, post-CG ||s|| = 9.05e-05, rs_new = 2.09e+02 (CG iters: 10)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-559153187.py in <cell line: 0>()
#      65
#      66         for cg_iter in range(cg_maxiter):
# ---> 67             Ap = energy_hvp(p_cg) + damping * p_cg
#      68             alpha_cg = rs_old / (torch.dot(p_cg, Ap) + 1e-12)
#      69             s += alpha_cg * p_cg
#
# /tmp/ipython-input-1487577490.py in energy_hvp(v_vec_full)
#      42         # 5. First-order gradient w.r.t. net_params
#      43         # --------------------------------------------------------------
# ---> 44         g_list = torch.autograd.grad(
#      45             energy, net_params,
#      46             create_graph=True,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     501         )
#     502     else:
# --> 503         result = _engine_run_backward(
#     504             outputs,
#     505             grad_outputs_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     827         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828     try:
# --> 829         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830             t_outputs, *args, **kwargs
#     831         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# after ENGD, same pattern:
model.eval()
r_after_ngd = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing = None)
after_ngd_pde = loss_fn(r_after_ngd).item()
with torch.no_grad():
    tau_p       = model(x_data).squeeze(-1)
    after_ngd_data = (tau_p - tau_data).pow(2).mean()
print(f" After ENGD → PDE {after_ngd_pde:.3e}, DATA {after_ngd_data:.3e}")

# saving the L-BFGS fine-tuned model
engd_model_path = 'engd_finetuned.pth'
torch.save(model.state_dict(), engd_model_path)
# Out:
#  After ENGD → PDE 1.413e-04, DATA 2.396e-03

# %% [markdown]
# ## Plotting the Results

# %% [markdown]
# ### Training Curves

# %%
# --------------------------------------------------------------
#  Plotting three separate loss evolutions
# --------------------------------------------------------------
adam_end   = n_epochs
lbfgs_end  = adam_end + len(lbfgs_total)
engd_end   = lbfgs_end + len(engd_total)

total_history = total_history + lbfgs_total + engd_total
pde_history   = pde_history + lbfgs_pde + engd_pde
data_history   = data_history + lbfgs_data + engd_data

# a) Total Loss
plt.figure(figsize=(6,4))
plt.semilogy(np.arange(adam_end), total_history[:adam_end], color='blue', label="ADAM")
plt.semilogy(np.arange(adam_end, lbfgs_end), total_history[adam_end:lbfgs_end], color='green', label="L-BFGS")
plt.semilogy(np.arange(lbfgs_end, engd_end), total_history[lbfgs_end:engd_end], color='red', label="ENGD")
plt.title("Total Loss vs Epoch / L-BFGS / ENGD step")
plt.xlabel("step (Adam epochs or L-BFGS/ENGD iter)")
plt.ylabel("loss_total")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.show()

# b) PDE Loss
plt.figure(figsize=(6,4))
plt.semilogy(np.arange(adam_end), pde_history[:adam_end], color='blue', label="ADAM")
plt.semilogy(np.arange(adam_end, lbfgs_end), pde_history[adam_end:lbfgs_end], color='green', label="L-BFGS")
plt.semilogy(np.arange(lbfgs_end, engd_end), pde_history[lbfgs_end:engd_end], color='red', label="ENGD")
plt.title("PDE Loss vs Epoch / L-BFGS / ENGD step")
plt.xlabel("step")
plt.ylabel("loss_pde")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.show()

# c) Data Loss
plt.figure(figsize=(6,4))
plt.semilogy(np.arange(adam_end), data_history[:adam_end], color='blue', label="ADAM")
plt.semilogy(np.arange(adam_end, lbfgs_end), data_history[adam_end:lbfgs_end], color='green', label="L-BFGS")
plt.semilogy(np.arange(lbfgs_end, engd_end), data_history[lbfgs_end:engd_end], color='red', label="ENGD")
plt.title("Data Loss vs Epoch / L-BFGS / ENGD step")
plt.xlabel("step")
plt.ylabel("loss_data")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.show()

# %% [markdown]
# ### Learned Solution vs FEM Solution

# %%
# Choose model to evaluate

choice = 2 #input("Enter 1, 2 or 3: ").strip()

model = BoundaryPINN(power, width, depth)
if choice == 1:
    model.load_state_dict(torch.load(adam_model_path))
    print("Loaded Adam-only model")
elif choice == 2:
    model.load_state_dict(torch.load(lbfgs_model_path))
    print("Loaded L-BFGS fine-tuned model")
elif choice == 3:
    model.load_state_dict(torch.load(engd_model_path))
    print("Loaded L-BFGS + ENGD fine-tuned model")
else:
    raise ValueError("Invalid choice")

model.to(device)
model.eval()
# Out:
# Loaded L-BFGS fine-tuned model
# BoundaryPINN(
#   (layers): ModuleList(
#     (0): Linear(in_features=2, out_features=30, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=30, out_features=30, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=30, out_features=1, bias=True)
#   )
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=30, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=30, out_features=30, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=30, out_features=1, bias=True)
#   )
# )

# %%
#Visualize PINN vs True tau

n_pts = 200
xx, yy = np.meshgrid(
    np.linspace(-a,a,n_pts),
    np.linspace(-b,b,n_pts)
)
mask = (xx/a)**2 + (yy/b)**2 <= 1.0
pts = np.vstack([xx[mask], yy[mask]]).T

with torch.no_grad():
    inp = torch.from_numpy(pts).to(device)
    pred = model(inp).cpu().numpy().squeeze(-1)

Zp = np.zeros_like(xx); Zt = np.zeros_like(xx)
Zp[mask] = pred
Zt[mask] = np.array([u_sol(x, y) for x, y in pts])

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))
cf1 = ax1.contourf(xx, yy, Zp, levels=50, cmap='viridis')
ax1.set_title('PINN tau')
fig.colorbar(cf1, ax=ax1, shrink=0.8)

cf2 = ax2.contourf(xx, yy, Zt, levels=50, cmap='viridis')
ax2.set_title('FEM tau')
fig.colorbar(cf2, ax=ax2, shrink=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relative and Pointwise error

# %%
# pointwise L1 error
Z_err = np.abs(Zp - Zt)
plt.figure(figsize=(6,5))
cf = plt.contourf(xx, yy, Z_err, levels=50, cmap='RdBu_r')
plt.colorbar(cf, label=r'$|\tau_{PINN}-\tau|$')
plt.title('Pointwise absolute‐error Field')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# average relative L2 error
#    ‖tau_pinn − tau_true‖₂ / ‖tau_true‖₂   (empirical L²(Ω) norm)
pred_vals = pred
true_vals = np.array([u_sol(x, y) for x, y in pts])

# Empirical L² norm of true solution: √( (1/n) Σ τ_true² )
tau_l2_norm = np.sqrt(np.mean(true_vals**2))
glob_rel_L2 = np.sqrt(np.mean((pred_vals - true_vals)**2)) / tau_l2_norm
print(f"Global relative L2 error: {glob_rel_L2:.3e} (true solution L2 norm: {tau_l2_norm:.3e})")

# average relative L1 error
#     ‖tau_pinn − tau_true‖₁ / ‖tau_true‖₁   (empirical L¹(Ω) norm)
tau_l1_norm = np.mean(np.abs(true_vals))
glob_rel_L1 = np.mean(np.abs(pred_vals - true_vals)) / tau_l1_norm
print(f"Global relative L1 error: {glob_rel_L1:.3e} (true solution L1 norm: {tau_l1_norm:.3e})")

# Sobolev H1 and H2 errors (finite difference on full grid)

# Compute grid spacings in x and y for the ellipse:
dx = (2 * a) / (n_pts - 1)
dy = (2 * b) / (n_pts - 1)

# Error field on the full grid
Z_err = Zp - Zt

# First derivatives of the error field using finite differences
derr_dy, derr_dx = np.gradient(Z_err, dy, dx)
grad_err_sq = derr_dx[mask]**2 + derr_dy[mask]**2

# Second derivatives of the error field
d2err_dx2 = np.gradient(derr_dx, dx, axis=1)
d2err_dy2 = np.gradient(derr_dy, dy, axis=0)
d2err_dxdy = np.gradient(derr_dy, dx, axis=1)
hess_err_sq = d2err_dx2[mask]**2 + d2err_dy2[mask]**2 + 2 * d2err_dxdy[mask]**2

# Compute derivatives for the true solution field (Zt) on the full grid
dt_dy, dt_dx = np.gradient(Zt, dy, dx)
grad_t_sq = dt_dx[mask]**2 + dt_dy[mask]**2

d2t_dx2 = np.gradient(dt_dx, dx, axis=1)
d2t_dy2 = np.gradient(dt_dy, dy, axis=0)
d2t_dxdy = np.gradient(dt_dy, dx, axis=1)
hess_t_sq = d2t_dx2[mask]**2 + d2t_dy2[mask]**2 + 2 * d2t_dxdy[mask]**2

# Compute the H¹ and H² norms of the true solution
tau_h1_norm = np.sqrt(np.mean(Zt[mask]**2 + grad_t_sq))
tau_h2_norm = np.sqrt(np.mean(Zt[mask]**2 + grad_t_sq + hess_t_sq))

# Global relative Sobolev error metrics
glob_rel_H1 = np.sqrt(np.mean(Z_err[mask]**2 + grad_err_sq)) / tau_h1_norm
glob_rel_H2 = np.sqrt(np.mean(Z_err[mask]**2 + grad_err_sq + hess_err_sq)) / tau_h2_norm

print(f"Global relative H1 error: {glob_rel_H1:.3e} (true solution H1 norm: {tau_h1_norm:.3e})")
print(f"Global relative H2 error: {glob_rel_H2:.3e} (true solution H2 norm: {tau_h2_norm:.3e})")

print(f"Final PDE loss: {after_pde:.3e}")
print(f"Final data loss: {after_data:.3e}")
# Out:
# Global relative L2 error: 2.588e-01 (true solution L2 norm: 9.538e-01)
# Global relative L1 error: 2.358e-01 (true solution L1 norm: 8.125e-01)
# Global relative H1 error: 3.171e-01 (true solution H1 norm: 1.834e+00)
# Global relative H2 error: 3.973e-01 (true solution H2 norm: 8.577e+00)
# Final PDE loss: 8.798e-05
# Final data loss: 2.344e-03

# %%
#  ENGD loop hyperparameters
'''engd_steps = n_epochs
damping = 5e-1
engd_lr = 5e-7
cg_maxiter = 10
cg_tol = 1e-9

for step in range(1, engd_steps + 1):
    model.zero_grad()

    # === PDE loss ===
    r = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing=None)
    pde_l = loss_fn(r)

    # === Data loss ===
    tau_p = model(x_data).squeeze(-1)
    data_l = (tau_p - tau_data).pow(2).mean()

    # === Total loss (EXACT same as L-BFGS) ===
    total_l = (torch.exp(-2 * model.log_sigma_pde) * pde_l +
               torch.exp(-2 * model.log_sigma_data) * data_l +
               model.log_sigma_pde + model.log_sigma_data)

    # === Logging (exclude log terms from total) ===
    engd_total.append(total_l.item() - (model.log_sigma_pde.item() + model.log_sigma_data.item()))
    engd_pde.append(pde_l.item())
    engd_data.append(data_l.item())

    # === Backward ===
    total_l.backward()
    g_flat = torch.cat([p.grad.view(-1) for p in model.parameters() if p.grad is not None])
    #g_norm = torch.norm(g_flat).item()
    #print(f"ENGD step {step}: pre-CG ||g|| = {g_norm:.2e}, total_loss = {total_l.item():.2e}")


    # === CG solve: (H + λI) s = -g ===
    s = torch.zeros_like(g_flat)
    r_cg = -g_flat.clone()
    p_cg = r_cg.clone()
    rs_old = torch.dot(r_cg, r_cg)

    for cg_iter in range(cg_maxiter):
        Ap = energy_hvp(p_cg) + damping * p_cg
        alpha = rs_old / (torch.dot(p_cg, Ap) + 1e-12)
        s += alpha * p_cg
        r_cg -= alpha * Ap
        rs_new = torch.dot(r_cg, r_cg)
        if torch.sqrt(rs_new) < cg_tol * torch.sqrt(rs_old):
            break
        p_cg = r_cg + (rs_new / rs_old) * p_cg
        rs_old = rs_new

    #s_norm = torch.norm(s).item()
    #print(f"ENGD step {step}: post-CG ||s|| = {s_norm:.2e}, rs_new = {rs_new:.2e} (CG iters: {_ + 1})")

    # === Update parameters ===
    offset = 0
    for p in model.parameters():
        if p.grad is None: continue
        numel = p.numel()
        p.data.add_(engd_lr * s[offset:offset + numel].view_as(p))
        offset += numel

    # === Print ===
    if step % 25 == 0 or step == engd_steps:
        s_norm = torch.norm(s).item()
        g_norm = torch.norm(g_flat).item()
        print(f"ENGD [{step:3d}/{engd_steps}] | "
              f"Total {engd_total[-1]:.2e} | PDE {pde_l:.2e} | Data {data_l:.2e}"
              f"\npre-CG ||g|| = {g_norm:.2e}, post-CG ||s|| = {s_norm:.2e}, rs_new = {rs_new:.2e} (CG iters: {cg_iter + 1})"
              )'''
# Out:
# 'engd_steps = n_epochs\ndamping = 5e-1\nengd_lr = 5e-7\ncg_maxiter = 10\ncg_tol = 1e-9\n\nfor step in range(1, engd_steps + 1):\n    model.zero_grad()\n\n    # === PDE loss ===\n    r = pde_residual(model, Xb_ft, A_np, nu_np, eps_np, forcing=None)\n    pde_l = loss_fn(r)\n\n    # === Data loss ===\n    tau_p = model(x_data).squeeze(-1)\n    data_l = (tau_p - tau_data).pow(2).mean()\n\n    # === Total loss (EXACT same as L-BFGS) ===\n    total_l = (torch.exp(-2 * model.log_sigma_pde) * pde_l +\n               torch.exp(-2 * model.log_sigma_data) * data_l +\n               model.log_sigma_pde + model.log_sigma_data)\n\n    # === Logging (exclude log terms from total) ===\n    engd_total.append(total_l.item() - (model.log_sigma_pde.item() + model.log_sigma_data.item()))\n    engd_pde.append(pde_l.item())\n    engd_data.append(data_l.item())\n\n    # === Backward ===\n    total_l.backward()\n    g_flat = torch.cat([p.grad.view(-1) for p in model.parameters() if p.grad is not None])\n    #g_norm = torch.norm(g_flat).item()\n    #print(f"ENGD step {step}: pre-CG ||g|| = {g_norm:.2e}, total_loss = {total_l.item():.2e}")\n\n\n    # === CG solve: (H + λI) s = -g ===\n    s = torch.zeros_like(g_flat)\n    r_cg = -g_flat.clone()\n    p_cg = r_cg.clone()\n    rs_old = torch.dot(r_cg, r_cg)\n\n    for cg_iter in range(cg_maxiter):\n        Ap = energy_hvp(p_cg) + damping * p_cg\n        alpha = rs_old / (torch.dot(p_cg, Ap) + 1e-12)\n        s += alpha * p_cg\n        r_cg -= alpha * Ap\n        rs_new = torch.dot(r_cg, r_cg)\n        if torch.sqrt(rs_new) < cg_tol * torch.sqrt(rs_old):\n            break\n        p_cg = r_cg + (rs_new / rs_old) * p_cg\n        rs_old = rs_new\n\n    #s_norm = torch.norm(s).item()\n    #print(f"ENGD step {step}: post-CG ||s|| = {s_norm:.2e}, rs_new = {rs_new:.2e} (CG iters: {_ + 1})")\n\n    # === Update parameters ===\n    offset = 0\n    for p in model.parameters():\n        if p.grad is None: continue\n        numel = p.numel()\n        p.data.add_(engd_lr * s[offset:offset + numel].view_as(p))\n        offset += numel\n\n    # === Print ===\n    if step % 25 == 0 or step == engd_steps:\n        s_norm = torch.norm(s).item()\n        g_norm = torch.norm(g_flat).item()\n        print(f"ENGD [{step:3d}/{engd_steps}] | "\n              f"Total {engd_total[-1]:.2e} | PDE {pde_l:.2e} | Data {data_l:.2e}"\n              f"\npre-CG ||g|| = {g_norm:.2e}, post-CG ||s|| = {s_norm:.2e}, rs_new = {rs_new:.2e} (CG iters: {cg_iter + 1})"\n              )'
