# %% [markdown]
# <a href="https://colab.research.google.com/github/StratosFair/Mean_Escape_Time/blob/main/OU_process_2D/Models/%5BFINAL%5Dvariational_pinn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports & FP64
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import scipy.special as special

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_dtype(torch.float64)

# %% [markdown]
# # Solving for the MET of an Ornstein-Uhlenbeck process in a disk with Variational PINNs and Nitsche's method: comparison with exact solution

# %% [markdown]
# ## 1) Setup
#
# For $\theta,\sigma,r >0$ some fixed parameters, we let $\Omega := B_r \equiv \{x\in\mathbb R^d : \|x\|< r \}$, and define the process ($d=2$ in our illustration) :
#
# $$\begin{cases} dX_t &= -\theta X_t dt + \sigma dB_t \\
# X_0 &= x \in \Omega \end{cases} $$
#
# For all $x\in\Omega$, let
#
# $$T(x) := \inf\{t\ge 0 : X_t \in\partial\Omega\} $$
#
# and let its first moment be denoted
#
# $$\tau(x) := \mathbb E[T(x)] $$
#
# We can show under some regularity conditions on $\Omega$ that $\tau$ is the (unique) solution of the BVP :
#
# $$\begin{cases} -\mathcal{L}u(x) &= 1 \text{ for all } x\in\Omega \\
# u(x) &= 0 \text{ for all } x\in\partial\Omega \end{cases} $$
#
# where $\mathcal L$ is the infinitesimal generator of the Ornstein-Uhlenbeck process, given by
# $$\mathcal Lu : x \mapsto -\theta x \cdot \nabla u(x) + \frac{\sigma^2}{2}\Delta u(x) $$

# %% [markdown]
# Nicely enough, for this problem, we can compare our solution with the known closed-form solution (see https://arxiv.org/abs/2208.04029) :
#
# $$ \tau(x) := \frac{1}{\lambda^{d/2}\sigma^2}\int_\rho^r z^{1-d} e^{\lambda z^2} \gamma(d/2, \lambda z^2)\ dz $$
#
# where $\lambda := \theta/\sigma^2 $, $\rho := \|x\| $ and $\gamma$ is the upper incomplete gamma function :
# $$\gamma(n,y) := \int_0^y t^{n-1} e^{-t}\ dt.  $$

# %%
# Problem Parameters & True Solution
R = 2.0
theta = 3.0
sigma2 = 2.0
sigma = np.sqrt(sigma2)

def true_tau(x, y, theta=theta, sigma=sigma, R=R):
    lam = theta / sigma**2
    rho = np.sqrt(x**2 + y**2)
    integrand = lambda t: np.exp(lam * t**2) * special.gammainc(1, lam * t**2) / t
    I, _ = integrate.quad(integrand, rho, R)
    return I / theta

true_tau_vec = np.vectorize(true_tau)

# %%
n_pts = 200
xx, yy = np.meshgrid(
    np.linspace(-R,R,n_pts),
    np.linspace(-R,R,n_pts)
)
mask = xx**2 + yy**2 <= R**2
pts = np.vstack([xx[mask], yy[mask]]).T

Zp = np.zeros_like(xx)
Zp[mask] = true_tau_vec(xx[mask], yy[mask])

fig, ax = plt.subplots()
cf2 = ax.contourf(xx, yy, Zp, levels=50, cmap='viridis')
ax.set_title('True tau')
fig.colorbar(cf2, ax=ax, shrink=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2) Neural Network architecture and loss function
#
# Unlike the standard PINN, we use a variational PINN (VPINN) with Nitsche’s method to weakly enforce the homogeneous Dirichlet boundary condition. Specifically, we seek $u \in H^1(\Omega)$ such that:
#
# $$a(u, v) = \int_\Omega \left( \frac{\sigma^2}{2} \nabla u \cdot \nabla v - \theta (x \cdot \nabla u) v \right) dx - \int_{\partial \Omega} \frac{\sigma^2}{2} (\nabla u \cdot n) v \, ds - \int_{\partial \Omega} u \left( \frac{\sigma^2}{2} \nabla v \cdot n \right) ds + \beta \int_{\partial \Omega} u v \, ds = -\int_\Omega v \, dx = l(v),$$
#
# for all test functions $v \in H^1(\Omega)$, where $\partial \Omega = \{ x : \|x\| = R \}$, $n$ is the outward normal, and $\beta > 0$ is a penalty parameter.
#
# With this formulation, our objective to minimize becomes:
#
# $$\hat{u} := \arg\min_{u \in \mathcal{NN}} \frac{1}{K_{\text{test}}} \sum_{k=1}^{K_{\text{test}}} \left( a(u, \phi_k) - l(\phi_k) \right)^2,$$
#
# where $\phi_k(x) = \exp(-\|x - c_k\|^2 / (2 s_{\text{test}}^2))$, $k=1,\dots,K_{\text{test}}$, are Gaussian test functions with centers $c_k$ sampled uniformly in $\Omega$, and integrals are approximated via Monte Carlo sampling: domain integrals use points $x_i^c$ sampled i.i.d. uniformly in $\Omega$, scaled by $\pi R^2$, and boundary integrals use points on $\partial \Omega$, scaled by $2\pi R$.
#
# The hypothesis space is defined as:
#
# $$\mathcal{NN} := \left\{ x \mapsto T_L \circ \sigma \circ T_{L-1} \circ \cdots \circ \sigma \circ T_1 (x) \right\},$$
#
# for
#
# $$T_\ell : \mathbb{R}^{\ell-1} \to \mathbb{R}^\ell$$
#
# affine-linear maps of appropriate input-output dimensions, where
#
# $$\sigma : x \mapsto \begin{cases} x^2 & \text{if } x \geq 0 \\ 0 & \text{if } x \leq 0 \end{cases} \quad \text{OR} \quad \sigma : x \mapsto \tanh(x),$$
#
# is either the ReQU or hyperbolic tangent activation function, which is understood element-wise when applied to vectors.

# %% [markdown]
# ## 2) Neural Network architecture and loss function
# Unlike the standard PINN, we use a variational PINN (VPINN) with Nitsche’s method to weakly enforce the homogeneous Dirichlet boundary condition. Specifically, we seek $u \in H^1(\Omega)$ such that:
# $$a(u, v) = \int_\Omega \left( \frac{\sigma^2}{2} \nabla u \cdot \nabla v + \theta (x \cdot \nabla u) v \right) dx - \int_{\partial \Omega} \frac{\sigma^2}{2} (\nabla u \cdot n) v \, ds - \int_{\partial \Omega} u \left( \frac{\sigma^2}{2} \nabla v \cdot n \right) ds + \beta \int_{\partial \Omega} u v \, ds = \int_\Omega v \, dx = l(v),$$
# for all test functions $v \in H^1(\Omega)$, where $\partial \Omega = \{ x : \|x\| = R \}$, $n$ is the outward normal, and $\beta > 0$ is a penalty parameter.
# With this formulation, our objective to minimize becomes:
# $$\hat{u} := \arg\min_{u \in \mathcal{NN}} \frac{1}{K_{\text{test}}} \sum_{k=1}^{K_{\text{test}}} \left( a(u, \phi_k) - l(\phi_k) \right)^2,$$
# where $\phi_k(x) = \exp(-\|x - c_k\|^2 / (2 s_{\text{test}}^2))$, $k=1,\dots,K_{\text{test}}$, are Gaussian test functions with centers $c_k$ sampled uniformly in $\Omega$, and integrals are approximated via Monte Carlo sampling: domain integrals use points $x_i^c$ sampled i.i.d. uniformly in $\Omega$, scaled by $\pi R^2$, and boundary integrals use points on $\partial \Omega$, scaled by $2\pi R$.
# The hypothesis space is defined as:
# $$\mathcal{NN} := \left\{ x \mapsto T_L \circ \sigma \circ T_{L-1} \circ \cdots \circ \sigma \circ T_1 (x) \right\},$$
# for
# $$T_\ell : \mathbb{R}^{\ell-1} \to \mathbb{R}^\ell$$
# affine-linear maps of appropriate input-output dimensions, where
# $$\sigma : x \mapsto \begin{cases} x^2 & \text{if } x \geq 0 \\ 0 & \text{if } x \leq 0 \end{cases} \quad \text{OR} \quad \sigma : x \mapsto \tanh(x),$$
# is either the ReQU or hyperbolic tangent activation function, which is understood element-wise when applied to vectors.

# %%
# defining PINN w/ matching boundary condition
power = None #exponent k for relu^k, none for tanh
width = 30
depth = 3
gain = 2.0 #magnitude of weights at initialization

#define ReLU^k activation

class RePU(nn.Module):
    def __init__(self, power = power):
        super(RePU, self).__init__()
        self.power = power

    def forward(self, x):
        return torch.pow(torch.relu(x), self.power)

#define the smooth distance approximation
def smooth_distance(x, log_factor):
    norm_x = torch.linalg.norm(x, dim=-1)
    dist =  (R**2 - norm_x**2)/(2*R)
    return dist * torch.exp(log_factor)

#define hypothesis space
# Model definition (standard MLP, no boundary enforcement in architecture)
class VariationalPINN(nn.Module):
    def __init__(self, power=power, width=width, depth=depth):
        super().__init__()
        self.layers = nn.ModuleList()
        self.layers.append(nn.Linear(2, width))
        if isinstance(power, int):
            self.layers.append(RePU(power))
        else:
            self.layers.append(nn.Tanh())
        for _ in range(depth - 1):
            self.layers.append(nn.Linear(width, width))
            self.layers.append(nn.Tanh() if power is None else RePU(power))
        self.layers.append(nn.Linear(width, 1))
        self.mlp = nn.Sequential(*self.layers)

        # Learnable weights for dynamic loss balancing
        self.log_sigma_var  = nn.Parameter(torch.tensor(-0.5, dtype=torch.float64))
        self.log_sigma_data = nn.Parameter(torch.tensor(-0.5, dtype=torch.float64))
        self.log_sigma_bc   = nn.Parameter(torch.tensor( 3.0, dtype=torch.float64))

    def forward(self, x):
        return self.mlp(x).squeeze(-1)

#weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_normal_(m.weight, gain=gain)
        m.bias.data.fill_(gain)

# %%
# Variational residual with Nitsche's method (weak form + BC enforcement)
def variational_residual(model, X_int, X_bd, c_test, s_test, theta=theta, sigma=sigma):
    """
    Compute average squared variational residual over Gaussian test functions.
    Includes Nitsche terms for Dirichlet BC u=0 on boundary.
    """
    X_int = X_int.detach().requires_grad_(True)
    X_bd = X_bd.detach().requires_grad_(True)

    # Interior points
    u_int = model(X_int)
    grad_u_int = torch.autograd.grad(u_int.sum(), X_int, create_graph=True)[0]  # [N,2]

    # Test functions φ_k and ∇φ_k on interior
    dx_int = X_int[:, None, :] - c_test[None, :, :]  # [N, K, 2]
    dist_sq_int = torch.sum(dx_int**2, dim=-1)       # [N, K]
    phi_int = torch.exp(-dist_sq_int / (2 * s_test**2))
    grad_phi_int = -dx_int / (s_test**2) * phi_int[..., None]  # [N, K, 2]

    # Test functions on boundary
    dx_bd = X_bd[:, None, :] - c_test[None, :, :]
    dist_sq_bd = torch.sum(dx_bd**2, dim=-1)
    phi_bd = torch.exp(-dist_sq_bd / (2 * s_test**2))
    grad_phi_bd = -dx_bd / (s_test**2) * phi_bd[..., None]

    A = sigma**2 / 2.0
    area = math.pi * R**2
    arclen = 2 * math.pi * R

    # Bilinear form a(u, φ_k) ≈ ∫ (A ∇u · ∇φ + (θx)·∇u φ) dx
    dot_grad = torch.sum(grad_u_int[:, None, :] * grad_phi_int, dim=-1)  # [N, K]
    b_term = theta * torch.sum(X_int[:, None, :] * grad_u_int[:, None, :] * phi_int[..., None], dim=-1).squeeze(-1)
    a_k = (A * dot_grad + b_term).mean(0) * area

    # Linear form F(φ_k) = ∫ 1 * φ_k dx
    F_k = phi_int.mean(0) * area

    # Nitsche consistency term: -∫ (∇u · n) φ ds
    n_bd = X_bd / R  # outward normal
    u_bd = model(X_bd)
    grad_u_bd = torch.autograd.grad(u_bd.sum(), X_bd, create_graph=True)[0]  # [M,2]
    flux_u = torch.sum(grad_u_bd[:, None, :] * n_bd[:, None, :], dim=-1)  # [M, K]
    consistency_k = -A * (flux_u * phi_bd).mean(0) * arclen

    # Nitsche symmetry term: -∫ u (∇φ · n) ds
    flux_phi = torch.sum(n_bd[:, None, :] * grad_phi_bd, dim=-1)  # [M, K]
    symmetry_k = -A * (u_bd[:, None] * flux_phi).mean(0) * arclen

    # Nitsche penalty term: +β ∫ u φ ds  (g=0)
    raw_penalty_k = (u_bd[:, None] * phi_bd).mean(0) * arclen

    # Total variational residual per test function
    r_interior_k = a_k - F_k + consistency_k + symmetry_k   # <-- only this line changed (RHS sign)
    return r_interior_k, raw_penalty_k

def var_loss_fn(r_k):
    return torch.mean(r_k.pow(2))

# %%
def empirical_h2_norm(model, x_batch):
    """
    Empirical H² norm of the *raw* NN output u(x) = model.raw_forward(x)
    computed exactly like your pde_residual (component-wise gradients).

    Returns a scalar tensor (mean over the batch).
    """
    # ------------------------------------------------------------------
    # 1) Prepare the input exactly as in pde_residual
    # ------------------------------------------------------------------
    x = x_batch.clone().detach().requires_grad_(True)   # shape [N,2]

    # ------------------------------------------------------------------
    # 2) 0-th order term :  u²
    # ------------------------------------------------------------------
    u = model(x)                # [N,1]
    u_sq = torch.mean(u.pow(2))              # scalar

    # ------------------------------------------------------------------
    # 3) 1-st order term :  |∇u|²  =  u_x² + u_y²
    # ------------------------------------------------------------------
    grad_u = torch.autograd.grad(
        u, x,
        grad_outputs=torch.ones_like(u),
        create_graph=True,
        retain_graph=True
    )[0]                                     # [N,2]
    u_x, u_y = grad_u[:, 0], grad_u[:, 1]

    grad_sq = torch.mean(u_x.pow(2) + u_y.pow(2))   # scalar

    # ------------------------------------------------------------------
    # 4) 2-nd order term :  ||∇²u||_F²  =  u_xx² + u_xy² + u_yx² + u_yy²
    # ------------------------------------------------------------------
    #   u_xx
    u_xx = torch.autograd.grad(
        u_x, x,
        grad_outputs=torch.ones_like(u_x),
        create_graph=True,
        retain_graph=True
    )[0][:, 0]                               # [N]

    #   u_yy
    u_yy = torch.autograd.grad(
        u_y, x,
        grad_outputs=torch.ones_like(u_y),
        create_graph=True,
        retain_graph=True
    )[0][:, 1]                               # [N]

    #   mixed derivatives u_xy = ∂/∂y (u_x)  and  u_yx = ∂/∂x (u_y)
    #   (they are equal for C² functions, but we compute both to be safe)
    u_xy = torch.autograd.grad(
        u_x, x,
        grad_outputs=torch.ones_like(u_x),
        create_graph=True,
        retain_graph=True
    )[0][:, 1]                               # ∂/∂y of u_x  → [N]

    u_yx = torch.autograd.grad(
        u_y, x,
        grad_outputs=torch.ones_like(u_y),
        create_graph=True,
        retain_graph=True
    )[0][:, 0]                               # ∂/∂x of u_y  → [N]

    hessian_fro_sq = torch.mean(
        u_xx.pow(2) + u_xy.pow(2) + u_yx.pow(2) + u_yy.pow(2)
    )                                        # scalar

    # ------------------------------------------------------------------
    # 5) Assemble the full H² norm (mean over the batch)
    # ------------------------------------------------------------------
    h2 = u_sq + grad_sq + hessian_fro_sq
    return h2

# %% [markdown]
# # 3) Computing an approximate data penalty regularization
#
# We sample a small subset $x_1, \ldots, x_{n_{d}} \in \Omega$ of points for which we compute approximate values $\tau^{MC}(x_1), \ldots, \tau^{MC}(x_{n_{d}}) $ by Monte Carlo. we will then use them to define a "data-fidelity" penalty term in the loss function:
# $$\text{Penalty}(\hat\tau_{NN}) = \frac{\lambda_{d}}{n_{d}} \sum_{i=1}^{n_d} \left(\tau^{MC}(x_i) - \hat\tau_{NN}(x_i)\right)^2, $$
# where $\lambda_{d}$ is a positive regularization parameter.

# %%
# generating some approximate true solutions in the domain

# uniform sampling in disk of radius R
@torch.no_grad()
def sample_disk(batch_size, R):
    """
    Sample uniformly in the disk of radius R.
    """
    r = torch.sqrt(torch.rand(batch_size, device=device))  # sqrt for uniform area
    theta = 2 * torch.pi * torch.rand(batch_size, device=device)
    x = torch.stack([r * torch.cos(theta), r * torch.sin(theta)], dim=1)
    return R * x  # uniform in disk of radius R


# 2) monte-carlo (euler-maruyama) approximation of tau at these points
@torch.no_grad()
def mc_exit_time(x0, theta, sigma, R,
                 n_paths=128, dt=1e-3, max_steps=20000):
    """
    x0: [B,2] starting points
    Returns tau_hat: [B] = mean exit time from each x0.
    Any path still 'alive' after max_steps is counted as having exit time = max_steps*dt.
    """
    B = x0.shape[0]
    P = n_paths

    # Expand to per-path positions
    X = x0.unsqueeze(1).expand(B, P, 2).clone()  # [B,P,2]
    t = torch.zeros(B, P, device=device)         # running clock
    alive = torch.ones(B, P, dtype=torch.bool, device=device)
    sqrt_dt = sigma * (dt ** 0.5)

    # For progress tracking
    print_interval = max(1, max_steps // 100)
    total_paths = B * P
    exited_count = 0

    for step in range(max_steps):
        if not alive.any():
            break

        # Drift + noise, but only update those still alive
        X_alive = X[alive]
        drift    = -theta * X_alive * dt
        noise    = sqrt_dt * torch.randn_like(X_alive)
        X[alive] = X_alive + drift + noise
        t[alive] += dt

        # Mark newly-exited paths
        normsq = X[alive].pow(2).sum(dim=1)
        just_exited = (normsq >= R*R)

        if just_exited.any():
            idx_alive = alive.nonzero(as_tuple=False)  # [N,2]
            exited_idx = idx_alive[just_exited]
            alive[exited_idx[:,0], exited_idx[:,1]] = False
            exited_count += just_exited.sum().item()

        # Progress print
        if step % print_interval == 0 or step == max_steps - 1:
            frac_alive = alive.float().mean().item()
            current_t = step * dt
            print(f"Step {step:5d} | t = {current_t:6.2f} | alive: {frac_alive*100:5.2f}% "
                  f"({total_paths - exited_count}/{total_paths} exited)", flush=True)

    # Paths still alive get t = max_steps*dt automatically from the loop
    tau_hat = t.mean(dim=1)  # [B]

    # Warn if many paths didn't exit
    survived = alive.sum().item()
    if survived > 0:
        print(f"WARNING: {survived}/{B*P} paths did NOT exit by t = {max_steps*dt:.2f}")

    return tau_hat  # no gradient flows back

# %%
# defining Uniform Sampling functions in the disk and on the boundary
def sample_uniform_disk(N, R=R):
    theta = 2*np.pi * torch.rand(N, dtype=torch.float64, device=device)
    rho = R    * torch.sqrt(torch.rand(N, dtype=torch.float64, device=device))
    return torch.stack([rho*torch.cos(theta), rho*torch.sin(theta)], dim=1)  # [N,2]

def sample_boundary(N, R=R):
    theta = 2 * math.pi * torch.rand(N, device=device)
    x = R * torch.cos(theta)
    y = R * torch.sin(theta)
    return torch.stack([x, y], dim=1)

# %% [markdown]
# # 6) Training loop

# %% [markdown]
#  ## 6.1) Training Parameters

# %%
# Training parameters
pool_size        = 8192
n_batches        = 16
batch_size       = pool_size // n_batches
n_epochs         = 500 #10_000
learning_rate    = 5e-4

# model instantiation
model = VariationalPINN(power, width, depth).to(device)
model.apply(init_weights)

opt   = torch.optim.Adam(list(model.parameters()), lr=learning_rate)

# scheduler: every `epochs_between_decay` epochs, multiply lr by gamma
num_decays = 100
epochs_between_decay = n_epochs // num_decays
final_factor = 1e-3
gamma = np.exp(np.log(final_factor) / num_decays)

scheduler = torch.optim.lr_scheduler.StepLR(
    opt,
    step_size=epochs_between_decay,  # decay every N epochs
    gamma=gamma                      # LR *= gamma at each decay
)

# %%
# Test function centers and hyperparameters
K_test = 50
s_test = R / 5.0
c_test = sample_uniform_disk(K_test, R=R)
area = math.pi * R**2
arclen = 2 * math.pi * R

# %% [markdown]
# ## 6.2) Generating the "data-fidelity" samples

# %%
# sample x_data
x_data = sample_disk(batch_size//2, R = R,)
max_time = 30
dt = 5e-3 #5e-4

# precompute tau_data once (theta, sigma are fixed PDE params)
tau_data = mc_exit_time(
    x0       = x_data,
    theta    = theta,
    sigma    = sigma,
    R        = R,
    n_paths  = 32,#256,
    dt       = dt,
    max_steps= int(max_time / dt)
)
# Out:
# Step     0 | t =   0.00 | alive: 96.04% (7868/8192 exited)
# Step    60 | t =   0.30 | alive: 82.40% (6750/8192 exited)
# Step   120 | t =   0.60 | alive: 80.47% (6592/8192 exited)
# Step   180 | t =   0.90 | alive: 79.03% (6474/8192 exited)
# Step   240 | t =   1.20 | alive: 77.71% (6366/8192 exited)
# Step   300 | t =   1.50 | alive: 76.37% (6256/8192 exited)
# Step   360 | t =   1.80 | alive: 75.17% (6158/8192 exited)
# Step   420 | t =   2.10 | alive: 73.84% (6049/8192 exited)
# Step   480 | t =   2.40 | alive: 72.51% (5940/8192 exited)
# Step   540 | t =   2.70 | alive: 71.24% (5836/8192 exited)
# Step   600 | t =   3.00 | alive: 70.02% (5736/8192 exited)
# Step   660 | t =   3.30 | alive: 68.82% (5638/8192 exited)
# Step   720 | t =   3.60 | alive: 67.71% (5547/8192 exited)
# Step   780 | t =   3.90 | alive: 66.42% (5441/8192 exited)
# Step   840 | t =   4.20 | alive: 65.36% (5354/8192 exited)
# Step   900 | t =   4.50 | alive: 63.98% (5241/8192 exited)
# Step   960 | t =   4.80 | alive: 62.83% (5147/8192 exited)
# Step  1020 | t =   5.10 | alive: 61.84% (5066/8192 exited)
# Step  1080 | t =   5.40 | alive: 60.90% (4989/8192 exited)
# Step  1140 | t =   5.70 | alive: 60.10% (4923/8192 exited)
# Step  1200 | t =   6.00 | alive: 58.76% (4814/8192 exited)
# Step  1260 | t =   6.30 | alive: 57.75% (4731/8192 exited)
# Step  1320 | t =   6.60 | alive: 56.69% (4644/8192 exited)
# Step  1380 | t =   6.90 | alive: 55.66% (4560/8192 exited)
# Step  1440 | t =   7.20 | alive: 54.80% (4489/8192 exited)
# Step  1500 | t =   7.50 | alive: 53.82% (4409/8192 exited)
# Step  1560 | t =   7.80 | alive: 52.94% (4337/8192 exited)
# Step  1620 | t =   8.10 | alive: 51.95% (4256/8192 exited)
# Step  1680 | t =   8.40 | alive: 50.84% (4165/8192 exited)
# Step  1740 | t =   8.70 | alive: 50.00% (4096/8192 exited)
# Step  1800 | t =   9.00 | alive: 49.08% (4021/8192 exited)
# Step  1860 | t =   9.30 | alive: 48.18% (3947/8192 exited)
# Step  1920 | t =   9.60 | alive: 47.46% (3888/8192 exited)
# Step  1980 | t =   9.90 | alive: 46.81% (3835/8192 exited)
# Step  2040 | t =  10.20 | alive: 46.02% (3770/8192 exited)
# Step  2100 | t =  10.50 | alive: 45.10% (3695/8192 exited)
# Step  2160 | t =  10.80 | alive: 44.42% (3639/8192 exited)
# Step  2220 | t =  11.10 | alive: 43.64% (3575/8192 exited)
# Step  2280 | t =  11.40 | alive: 42.93% (3517/8192 exited)
# Step  2340 | t =  11.70 | alive: 42.15% (3453/8192 exited)
# Step  2400 | t =  12.00 | alive: 41.44% (3395/8192 exited)
# Step  2460 | t =  12.30 | alive: 40.77% (3340/8192 exited)
# Step  2520 | t =  12.60 | alive: 39.97% (3274/8192 exited)
# Step  2580 | t =  12.90 | alive: 39.38% (3226/8192 exited)
# Step  2640 | t =  13.20 | alive: 38.62% (3164/8192 exited)
# Step  2700 | t =  13.50 | alive: 38.11% (3122/8192 exited)
# Step  2760 | t =  13.80 | alive: 37.41% (3065/8192 exited)
# Step  2820 | t =  14.10 | alive: 36.72% (3008/8192 exited)
# Step  2880 | t =  14.40 | alive: 36.08% (2956/8192 exited)
# Step  2940 | t =  14.70 | alive: 35.38% (2898/8192 exited)
# Step  3000 | t =  15.00 | alive: 34.84% (2854/8192 exited)
# Step  3060 | t =  15.30 | alive: 34.31% (2811/8192 exited)
# Step  3120 | t =  15.60 | alive: 33.78% (2767/8192 exited)
# Step  3180 | t =  15.90 | alive: 33.25% (2724/8192 exited)
# Step  3240 | t =  16.20 | alive: 32.74% (2682/8192 exited)
# Step  3300 | t =  16.50 | alive: 32.13% (2632/8192 exited)
# Step  3360 | t =  16.80 | alive: 31.40% (2572/8192 exited)
# Step  3420 | t =  17.10 | alive: 30.88% (2530/8192 exited)
# Step  3480 | t =  17.40 | alive: 30.40% (2490/8192 exited)
# Step  3540 | t =  17.70 | alive: 29.90% (2449/8192 exited)
# Step  3600 | t =  18.00 | alive: 29.22% (2394/8192 exited)
# Step  3660 | t =  18.30 | alive: 28.76% (2356/8192 exited)
# Step  3720 | t =  18.60 | alive: 28.23% (2313/8192 exited)
# Step  3780 | t =  18.90 | alive: 27.76% (2274/8192 exited)
# Step  3840 | t =  19.20 | alive: 27.33% (2239/8192 exited)
# Step  3900 | t =  19.50 | alive: 26.81% (2196/8192 exited)
# Step  3960 | t =  19.80 | alive: 26.39% (2162/8192 exited)
# Step  4020 | t =  20.10 | alive: 25.96% (2127/8192 exited)
# Step  4080 | t =  20.40 | alive: 25.45% (2085/8192 exited)
# Step  4140 | t =  20.70 | alive: 25.02% (2050/8192 exited)
# Step  4200 | t =  21.00 | alive: 24.49% (2006/8192 exited)
# Step  4260 | t =  21.30 | alive: 24.00% (1966/8192 exited)
# Step  4320 | t =  21.60 | alive: 23.71% (1942/8192 exited)
# Step  4380 | t =  21.90 | alive: 23.33% (1911/8192 exited)
# Step  4440 | t =  22.20 | alive: 23.01% (1885/8192 exited)
# Step  4500 | t =  22.50 | alive: 22.56% (1848/8192 exited)
# Step  4560 | t =  22.80 | alive: 22.17% (1816/8192 exited)
# Step  4620 | t =  23.10 | alive: 21.73% (1780/8192 exited)
# Step  4680 | t =  23.40 | alive: 21.30% (1745/8192 exited)
# Step  4740 | t =  23.70 | alive: 21.02% (1722/8192 exited)
# Step  4800 | t =  24.00 | alive: 20.64% (1691/8192 exited)
# Step  4860 | t =  24.30 | alive: 20.30% (1663/8192 exited)
# Step  4920 | t =  24.60 | alive: 20.06% (1643/8192 exited)
# Step  4980 | t =  24.90 | alive: 19.73% (1616/8192 exited)
# Step  5040 | t =  25.20 | alive: 19.35% (1585/8192 exited)
# Step  5100 | t =  25.50 | alive: 19.02% (1558/8192 exited)
# Step  5160 | t =  25.80 | alive: 18.81% (1541/8192 exited)
# Step  5220 | t =  26.10 | alive: 18.63% (1526/8192 exited)
# Step  5280 | t =  26.40 | alive: 18.27% (1497/8192 exited)
# Step  5340 | t =  26.70 | alive: 17.90% (1466/8192 exited)
# Step  5400 | t =  27.00 | alive: 17.65% (1446/8192 exited)
# Step  5460 | t =  27.30 | alive: 17.36% (1422/8192 exited)
# Step  5520 | t =  27.60 | alive: 17.13% (1403/8192 exited)
# Step  5580 | t =  27.90 | alive: 16.85% (1380/8192 exited)
# Step  5640 | t =  28.20 | alive: 16.41% (1344/8192 exited)
# Step  5700 | t =  28.50 | alive: 16.17% (1325/8192 exited)
# Step  5760 | t =  28.80 | alive: 15.88% (1301/8192 exited)
# Step  5820 | t =  29.10 | alive: 15.65% (1282/8192 exited)
# Step  5880 | t =  29.40 | alive: 15.30% (1253/8192 exited)
# Step  5940 | t =  29.70 | alive: 15.06% (1234/8192 exited)
# Step  5999 | t =  30.00 | alive: 14.78% (1211/8192 exited)
# WARNING: 1211/8192 paths did NOT exit by t = 30.00

# %% [markdown]
# ## 6.4) Start the Training with Adam

# %%
# Training Loop w/ Loss Logging

# prep for best‐model tracking
best_loss       = float("inf")
adam_model_path = "best_adam.pth"
best_epoch = 0
eval_Xb = sample_uniform_disk(pool_size, R=R) #to evaluate the model
eval_xbc = sample_boundary(pool_size//4)

total_history = []
var_history   = []
bc_history    = []
data_history  = []

for ep in range(n_epochs):
    opt.zero_grad()

    X_int = sample_uniform_disk(batch_size)
    X_bd = sample_boundary(batch_size)

    r_interior_k, penalty_k = variational_residual(model, X_int, X_bd, c_test, s_test, theta, sigma)
    loss_var = var_loss_fn(r_interior_k)
    loss_bc  = var_loss_fn(penalty_k)

    tau_pred = model(x_data)
    loss_data = (tau_pred - tau_data).pow(2).mean()

    loss_total = (
        torch.exp(-2 * model.log_sigma_var) * loss_var +
        torch.exp(-2 * model.log_sigma_bc ) * loss_bc +
        torch.exp(-2 * model.log_sigma_data) * loss_data +
        model.log_sigma_var + model.log_sigma_data +  model.log_sigma_bc
    )

    loss_total.backward()
    opt.step()
    scheduler.step()

    #eval
    r_k_eval, bc_eval   = variational_residual(model, eval_Xb, eval_xbc, c_test, s_test, theta, sigma)
    loss_eval     = var_loss_fn(r_k_eval) + var_loss_fn(r_k_eval)

    if loss_eval < best_loss or ep - best_epoch >= epochs_between_decay * 10 :
        best_loss = loss_eval
        torch.save(model.state_dict(), adam_model_path)
        best_epoch = ep

    total_history.append(loss_total.item()\
                            - (model.log_sigma_var.detach()\
                            + model.log_sigma_data.detach()
                            + model.log_sigma_bc.detach()).item()
                            )

    var_history.append(loss_var.item())
    bc_history.append(loss_bc.item())
    data_history.append(loss_data.item())

    if ep % 100 == 0:
        print(
            f"[ep {ep:4d}/{n_epochs}] "
            f"loss_var={loss_var:.2e}  "
            f"loss_bc={loss_bc:.2e}  "
            f"loss_data={loss_data:.2e}  "
        )
    if ep % 500 == 0:
        lr = scheduler.get_last_lr()[0]
        print(f"  → epoch {ep:4d},  lr={lr:.2e}")
# Out:
# [ep    0/500] loss_var=1.15e+00  loss_bc=3.18e-02  loss_data=1.41e+02
#   → epoch    0,  lr=5.00e-04
# [ep  100/500] loss_var=9.18e+00  loss_bc=7.73e+00  loss_data=4.97e+01
# [ep  200/500] loss_var=8.62e+00  loss_bc=8.36e+00  loss_data=3.92e+01
# [ep  300/500] loss_var=9.75e+00  loss_bc=9.82e+00  loss_data=3.73e+01
# [ep  400/500] loss_var=1.21e+01  loss_bc=9.74e+00  loss_data=3.69e+01

# %% [markdown]
# ## 6.5) L-BFGS Fine-Tuning

# %%
#LBFGS fine-tuning

# Reload best Adam snapshot
print(f"\nLoading best Adam model (loss={best_loss:.2e}, epoch={best_epoch}) …")
model.load_state_dict(torch.load(adam_model_path))
model.to(device)

# define L-BFGS parameters
lbfgs = torch.optim.LBFGS(
    model.parameters(),
    lr=1.0,
    max_iter=n_epochs//2,
    history_size=1000,
    tolerance_grad=1e-9,
    tolerance_change=1e-9,
    line_search_fn="strong_wolfe"
)

max_eval = lbfgs.defaults.get('max_eval')

# freeze one big PDE batch for the closure
X_int_ft = sample_uniform_disk(pool_size, R=R)
X_bd_ft = sample_boundary(pool_size)

lbfgs_total = []
lbfgs_var   = []
lbfgs_data  = []
lbfgs_bc    = []

def closure():
    closure.calls += 1
    lbfgs.zero_grad()

    r_k, bc_k = variational_residual(model, X_int_ft, X_bd_ft, c_test, s_test, theta, sigma)
    loss_var = var_loss_fn(r_k)
    loss_bc  = var_loss_fn(bc_k)

    tau_pred = model(x_data)
    loss_data = (tau_pred - tau_data).pow(2).mean()

    loss_total = (
        torch.exp(-2 * model.log_sigma_var) * loss_var +
        torch.exp(-2 * model.log_sigma_data) * loss_data +
        torch.exp(-2 * model.log_sigma_bc) * loss_bc +
        model.log_sigma_var + model.log_sigma_data + model.log_sigma_bc
    )

    # record
    lbfgs_total.append(loss_total.item() - \
            (model.log_sigma_var.detach()
            + model.log_sigma_data.detach()
            + model.log_sigma_bc.detach()
            ).item())
    lbfgs_var.append(loss_var.item())
    lbfgs_bc.append(loss_bc.item())
    lbfgs_data.append(loss_data.item())

    loss_total.backward()

    PRINT_EVERY = 100
    if closure.calls % PRINT_EVERY == 0:
        print(
            f"eval {closure.calls}/{max_eval} | "
            f"loss_var {loss_var:.2e} | "
            f"loss_bc {loss_bc:.2e} | "
            f"loss_data {loss_data:.2e}"
        )
    return loss_total

closure.calls = 0
# Out:
# Loading best Adam model (loss=1.59e+01, epoch=481) …

# %%
# report losses before/after lbfgs
# make sure model is in eval mode so e.g. Dropout/BatchNorm won’t move
model.eval()

# PDE loss
r_k_before, bc_before = variational_residual(model, X_int, X_bd, c_test, s_test, theta, sigma)
before_var = var_loss_fn(r_k_before).item()
before_bc =  var_loss_fn(bc_before).item()

# empirical Sobolev norm
#before_h2 = empirical_h2_norm(model, Xb_ft).item()

# data loss (doesn't need grads)
with torch.no_grad():
    tau_p       = model(x_data).squeeze(-1)
    before_data = (tau_p - tau_data).pow(2).mean()

print(f"Before L-BFGS → VARIATIONAL {before_var:.2e}, BOUNDARY {before_bc:.2e}, DATA {before_data:.2e}")

# running LBFGS
print("→ Running L-BFGS...")
loss_after = lbfgs.step(closure)
print(f"L-BFGS did {closure.calls} closure calls, final total loss = {loss_after:.2e}")
# Out:
# Before L-BFGS → VARIATIONAL 8.83e+00, BOUNDARY 1.11e+01, DATA 3.68e+01
# → Running L-BFGS...
# eval 100/312 | loss_var 2.91e-01 | loss_bc 1.51e+01 | loss_data 1.66e+01
# eval 200/312 | loss_var 3.96e-01 | loss_bc 6.13e-05 | loss_data 1.51e+02
# eval 300/312 | loss_var 4.29e-01 | loss_bc 1.20e-06 | loss_data 1.52e+02
# L-BFGS did 312 closure calls, final total loss = 1.17e+02

# %%
# after L-BFGS, same pattern:
model.eval()
r_k_after, bc_after = variational_residual(model, X_int, X_bd, c_test, s_test, theta, sigma)
after_var = var_loss_fn(r_k_after).item()
after_bc = var_loss_fn(bc_after).item()
#after_h2 = empirical_h2_norm(model, Xb_ft).item()
with torch.no_grad():
    tau_p       = model(x_data).squeeze(-1)
    after_data = (tau_p - tau_data).pow(2).mean()

print(f"After L-BFGS → VARIATIONAL {after_var:.2e}, BOUNDARY {after_bc:.2e}, DATA {after_data:.2e}")

# saving the L-BFGS fine-tuned model
lbfgs_model_path = 'lbfgs_finetuned.pth'
torch.save(model.state_dict(), lbfgs_model_path)
# Out:
# After L-BFGS → VARIATIONAL 8.62e-01, BOUNDARY 2.04e-05, DATA 1.52e+02

# %% [markdown]
# # 7) Plotting the results

# %% [markdown]
# ## 7.1) Training curves

# %%
# Plotting three separate loss eareautions
n = min(n_epochs, len(total_history))
total_history = total_history + lbfgs_total
var_history   = var_history   + lbfgs_var
bc_history    = bc_history    + lbfgs_bc
data_history  = data_history  + lbfgs_data


# a) Total Loss
plt.figure(figsize=(6,4))
plt.semilogy(np.arange(n), total_history[:n], \
             color = 'blue', label = "ADAM")
plt.semilogy(np.arange(n, len(total_history)), total_history[n:], \
             color = 'green', label = "L-BFGS")
plt.title("Total Loss vs Epoch / L-BFGS step")
plt.xlabel("step (Adam epochs or L-BFGS iter)")
plt.ylabel("loss_total")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.5)

# b) Variational Loss
plt.figure(figsize=(6,4))
plt.semilogy(np.arange(n), var_history[:n], \
             color = 'blue', label = "ADAM")
plt.semilogy(np.arange(n, len(var_history)), var_history[n:], \
             color = 'green', label = "L-BFGS")
plt.title("Variational Loss vs Epoch / L-BFGS step")
plt.xlabel("step")
plt.ylabel("loss_var")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.5)

# c) Boundary Loss
plt.figure(figsize=(6,4))
plt.semilogy(np.arange(n), bc_history[:n], \
             color = 'blue', label = "ADAM")
plt.semilogy(np.arange(n, len(bc_history)), bc_history[n:], \
             color = 'green', label = "L-BFGS")
plt.title("Boundary Loss vs Epoch / L-BFGS step")
plt.xlabel("step")
plt.ylabel("loss_bc")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.5)

# d) Data Loss
plt.figure(figsize=(6,4))
plt.semilogy(np.arange(n), data_history[:n], \
             color = 'blue', label = "ADAM")
plt.semilogy(np.arange(n, len(data_history)), data_history[n:], \
             color = 'green', label = "L-BFGS")
plt.title("Data Loss vs Epoch / L-BFGS step")
plt.xlabel("step")
plt.ylabel("loss_data")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.5)

plt.show()
# # c) Data Loss with homotopy
# plt.figure(figsize=(6,4))
# plt.semilogy(np.arange(n_hom), data_history[:n_hom], \
#              color = 'blue', label = "ADAM with homotopy")
# plt.semilogy(np.arange(n_hom, n_epochs), data_history[n_hom: n_epochs], \
#              color = 'orange', label = "Adam on true PDE")
# plt.semilogy(np.arange(n_epochs, len(pde_history)), data_history[n_epochs:], \
#              color = 'green', label = "L-BFGS on true PDE")
# plt.title("Data Loss vs Epoch / L-BFGS step")
# plt.xlabel("step")
# plt.ylabel("loss_data")
# plt.legend()
# plt.grid(True, which="both", ls="--", alpha=0.5)
#plt.show()

# %% [markdown]
# ## 7.2) Learned Solution vs True Solution

# %%
#choose to load the model fine-tuned with lbfgs or just the one trained with adam
load_fine_tuned = True #set to False for Adam-only model
model = VariationalPINN(power, width, depth)

if load_fine_tuned:
    model.load_state_dict(torch.load(lbfgs_model_path))
else:
    model.load_state_dict(torch.load(adam_model_path))
model.to(device)
model.eval()
# Out:
# VariationalPINN(
#   (layers): ModuleList(
#     (0): Linear(in_features=2, out_features=30, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=30, out_features=30, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=30, out_features=1, bias=True)
#   )
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=30, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=30, out_features=30, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=30, out_features=1, bias=True)
#   )
# )

# %%
# 9) Visualize PINN vs True tau

n_pts = 200
xx, yy = np.meshgrid(
    np.linspace(-R,R,n_pts),
    np.linspace(-R,R,n_pts)
)
mask = xx**2 + yy**2 <= R**2
pts = np.vstack([xx[mask], yy[mask]]).T

with torch.no_grad():
    inp = torch.from_numpy(pts).to(device)
    pred = model(inp).cpu().numpy()#.squeeze(-1)

Zp = np.zeros_like(xx); Zt = np.zeros_like(xx)
Zp[mask], Zt[mask] = pred, true_tau_vec(xx[mask], yy[mask])

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))
cf1 = ax1.contourf(xx, yy, Zp, levels=50, cmap='viridis')
ax1.set_title('PINN tau')
fig.colorbar(cf1, ax=ax1, shrink=0.8)

cf2 = ax2.contourf(xx, yy, Zt, levels=50, cmap='viridis')
ax2.set_title('True tau')
fig.colorbar(cf2, ax=ax2, shrink=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7.3) Relative and Pointwise error

# %%
# pointwise L1 error
Z_err = np.abs(Zp - Zt)
plt.figure(figsize=(6,5))
cf = plt.contourf(xx, yy, Z_err, levels=50, cmap='RdBu_r')
plt.colorbar(cf, label=r'$|\tau_{PINN}-\tau|$')
plt.title('Pointwise absolute‐error Field')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# average relative L2 error
#    ‖tau_pinn − tau_true‖₂ / ‖tau_true‖₂   (empirical L²(Ω) norm)
pred_vals = pred
true_vals = true_tau_vec(pts[:,0], pts[:,1])

# Empirical L² norm of true solution: √( (1/n) Σ τ_true² )
tau_l2_norm = np.sqrt(np.mean(true_vals**2))
glob_rel_L2 = np.sqrt(np.mean((pred_vals - true_vals)**2)) / tau_l2_norm
print(f"Global relative L2 error: {glob_rel_L2:.3e} (true solution L2 norm: {tau_l2_norm:.3e})")


# average relative L1 error
#     ‖tau_pinn − tau_true‖_1 / ‖tau_true‖_1   (empirical L¹(Ω) norm)
tau_l1_norm = np.mean(np.abs(true_vals))
glob_rel_L1 = np.mean(np.abs(pred_vals - true_vals)) / tau_l1_norm
print(f"Global relative L1 error: {glob_rel_L1:.3e} (true solution L1 norm: {tau_l1_norm:.3e})")

# Sobolev H1 and H2 errors (finite diff on full grid)
h = (2 * R) / (n_pts - 1)
Z_err = Zp - Zt
derr_dy, derr_dx = np.gradient(Z_err, h, h)
grad_err_sq = derr_dx[mask]**2 + derr_dy[mask]**2
d2err_dx2 = np.gradient(derr_dx, h, axis=1)
d2err_dy2 = np.gradient(derr_dy, h, axis=0)
d2err_dxdy = np.gradient(derr_dy, h, axis=1)
hess_err_sq = d2err_dx2[mask]**2 + d2err_dy2[mask]**2 + 2 * d2err_dxdy[mask]**2

# True solution norms
dt_dy, dt_dx = np.gradient(Zt, h, h)
grad_t_sq = dt_dx[mask]**2 + dt_dy[mask]**2
d2t_dx2 = np.gradient(dt_dx, h, axis=1)
d2t_dy2 = np.gradient(dt_dy, h, axis=0)
d2t_dxdy = np.gradient(dt_dy, h, axis=1)
hess_t_sq = d2t_dx2[mask]**2 + d2t_dy2[mask]**2 + 2 * d2t_dxdy[mask]**2

tau_h1_norm = np.sqrt(np.mean(Zt[mask]**2 + grad_t_sq))
tau_h2_norm = np.sqrt(np.mean(Zt[mask]**2 + grad_t_sq + hess_t_sq))
glob_rel_H1 = np.sqrt(np.mean(Z_err[mask]**2 + grad_err_sq)) / tau_h1_norm
glob_rel_H2 = np.sqrt(np.mean(Z_err[mask]**2 + grad_err_sq + hess_err_sq)) / tau_h2_norm

print(f"Global relative H1 error: {glob_rel_H1:.3e} (true solution H1 norm: {tau_h1_norm:.3e})")
print(f"Global relative H2 error: {glob_rel_H2:.3e} (true solution H2 norm: {tau_h2_norm:.3e})")

print(f"Final Variational loss: {after_var:.3e}")
print(f"Final boundary loss: {after_bc:.3e}")
print(f"Final data loss: {after_data:.3e}")
# Out:
# Global relative L2 error: 1.003e+00 (true solution L2 norm: 1.155e+01)
# Global relative L1 error: 1.002e+00 (true solution L1 norm: 1.103e+01)
# Global relative H1 error: 9.993e-01 (true solution H1 norm: 2.266e+01)
# Global relative H2 error: 9.999e-01 (true solution H2 norm: 1.841e+02)
# Final Variational loss: 8.624e-01
# Final boundary loss: 2.036e-05
# Final data loss: 1.522e+02
